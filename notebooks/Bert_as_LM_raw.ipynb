# %% [markdown]
# # Estimate sentence probability with BERT
# ## Calculating probability more properly:
# P_f, P_b: Probability forward pass, backward pass, respectively
# ```
# P_f = P(w_0) * P(w_1|w_0) * P(w_2|w_0, w_1) * ... * P(w_N)
# P_b = P(w_N-1|w_N) * P(w_N-2|w_N-1, w_N) * ... * P(w_0|w_1, w_2, ... ,w_N)
# ```
# In this notebook, probabilities are not normalized by sentence length, so `P_f`, `P_b` become smaller as the sentence length increases.
#
# Finally, the sentence probability P(S) is the geometric mean of forward and backwards probabilities:
# ```
# P(S) = (mean(P_f(S)) * mean(P_b(S))) ^ (1/2)
# ```

# %%
import numpy as np
import torch
from transformers import BertTokenizer, BertForMaskedLM

BOS_TOKEN = '[CLS]'
EOS_TOKEN = '[SEP]'
MASK_TOKEN = '[MASK]'

# Load pre-trained model (weights)
with torch.no_grad():
    model = BertForMaskedLM.from_pretrained('bert-large-uncased')
    model = BertForMaskedLM.from_pretrained('bert-base-uncased')
    model.eval()
    # Load pre-trained model tokenizer (vocabulary)
    tokenizer = BertTokenizer.from_pretrained('bert-large-uncased')
    tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# %%
def print_top_predictions(probs, k=5):
    probs = probs.detach().numpy()
    top_indexes = np.argpartition(probs, -k)[-k:]
    sorted_indexes = top_indexes[np.argsort(-probs[top_indexes])]
    top_tokens = tokenizer.convert_ids_to_tokens(sorted_indexes)
    print(f"Ordered top predicted tokens: {top_tokens}")
    print(f"Ordered top predicted values: {probs[sorted_indexes]}")

# %%
def get_sentence_prob(sentence, verbose=True):
    # Pre-process sentence, adding special tokens
    tokenized_input = tokenizer.tokenize(sentence)
    if tokenized_input[0] != BOS_TOKEN:
        tokenized_input.insert(0, BOS_TOKEN)
    if tokenized_input[-1] != EOS_TOKEN:
        tokenized_input.append(EOS_TOKEN)
    sent_len = len(tokenized_input)
    ids_input = tokenizer.convert_tokens_to_ids(tokenized_input)
    print(f"Processing sentence: {tokenized_input}\n")
    
    sm = torch.nn.Softmax(dim=0) # used to convert last hidden state to probs
    
    log_sent_prob_forward = 0
    log_sent_prob_backwards = 0
    # Mask non-special tokens in forward and backwards directions; calculate their probabilities
    for i in range(1, len(tokenized_input) - 1):  # Don't loop first and last tokens
        probs_forward = get_directional_prob(sm, tokenized_input, i, 'forward', verbose=verbose)
        probs_backwards = get_directional_prob(sm, tokenized_input, i, 'backwards', verbose=verbose)
        log_prob_forward = probs_forward[ids_input[i]]  # Prediction for masked word
        log_prob_forward = np.log10(log_prob_forward.detach().numpy())
        log_prob_backwards = probs_backwards[ids_input[i]]  # Prediction for masked word
        log_prob_backwards = np.log10(log_prob_backwards.detach().numpy())
        log_sent_prob_forward += log_prob_forward
        log_sent_prob_backwards += log_prob_backwards

        if verbose:
            print(f"Word: {tokenized_input[i]} \t Log-Prob_forward: {log_prob_forward}; Log-Prob_backwards: {log_prob_backwards}")

    # Obtain geometric average of forward and backward probs
    log_geom_mean_sent_prob = 0.5 * (log_sent_prob_forward + log_sent_prob_backwards)
    if verbose:
        print(f"Raw forward sentence probability: {log_sent_prob_forward}")
        print(f"Raw backward sentence probability: {log_sent_prob_backwards}\n")
        print(f"Average normalized sentence prob: {log_geom_mean_sent_prob}\n")
    return np.power(10, log_geom_mean_sent_prob)

# %%
def get_directional_prob(sm, tokenized_input, i, direction, verbose=False):
    current_tokens = tokenized_input[:]
    if direction == 'backwards':
        current_tokens[1:i+1] = [MASK_TOKEN for j in range(i)]
    elif direction == 'forward':
        current_tokens[i:-1] = [MASK_TOKEN for j in range(len(tokenized_input) - 1 - i)]
    else:
        print("Direction can only be 'forward' or 'backwards'")
        exit()
    if verbose: 
        print()
        print(current_tokens)
        
    masked_input = torch.tensor([tokenizer.convert_tokens_to_ids(current_tokens)])
    predictions = model(masked_input)
    predictions = predictions[0]
    probs = sm(predictions[0, i]) # Softmax to get probabilities
    if verbose: 
        print_top_predictions(probs)
    
    return probs # Model predictions

# %%
get_sentence_prob("He was receiving quite a ridiculous the.")
# Out:
# Processing sentence: ['[CLS]', 'he', 'was', 'receiving', 'quite', 'a', 'ridiculous', 'the', '.', '[SEP]']
#
#
# ['[CLS]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['"', "'", '-', 'oh', 'then']
# Ordered top predicted values: [0.32555664 0.064494   0.0138153  0.01192483 0.01160424]
#
# ['[CLS]', '[MASK]', 'was', 'receiving', 'quite', 'a', 'ridiculous', 'the', '.', '[SEP]']
# Ordered top predicted tokens: ['i', 'she', 'he', 'it', 'jack']
# Ordered top predicted values: [0.3033052  0.28302258 0.26991323 0.00534671 0.00106846]
# Word: he 	 Log-Prob_forward: -2.9956727027893066; Log-Prob_backwards: -0.5687758922576904
#
# ['[CLS]', 'he', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['was', 'looked', 'started', 'said', 'stopped']
# Ordered top predicted values: [0.0795251  0.04593899 0.0360042  0.03072959 0.02925682]
#
# ['[CLS]', '[MASK]', '[MASK]', 'receiving', 'quite', 'a', 'ridiculous', 'the', '.', '[SEP]']
# Ordered top predicted tokens: ['was', 'is', 'am', 'started', 'were']
# Ordered top predicted values: [0.8971583  0.03254693 0.01357105 0.00900214 0.00897992]
# Word: was 	 Log-Prob_forward: -1.099495768547058; Log-Prob_backwards: -0.04713090881705284
#
# ['[CLS]', 'he', 'was', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['a', 'the', 'so', 'no', 'just']
# Ordered top predicted values: [0.52416307 0.058014   0.03905359 0.02062451 0.01647064]
#
# ['[CLS]', '[MASK]', '[MASK]', '[MASK]', 'quite', 'a', 'ridiculous', 'the', '.', '[SEP]']
# Ordered top predicted tokens: ['was', 'is', 'seemed', ',', 'made']
# Ordered top predicted values: [0.6912228  0.22554646 0.00784621 0.00626267 0.00568764]
# Word: receiving 	 Log-Prob_forward: -4.805018424987793; Log-Prob_backwards: -6.082233428955078
#
# ['[CLS]', 'he', 'was', 'receiving', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['a', 'the', 'his', 'no', 'some']
# Ordered top predicted values: [0.8230796  0.03106627 0.0164135  0.01149433 0.01109933]
#
# ['[CLS]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', 'a', 'ridiculous', 'the', '.', '[SEP]']
# Ordered top predicted tokens: ['was', 'such', 'is', 'in', 'had']
# Ordered top predicted values: [0.30473843 0.08241434 0.06940644 0.05247539 0.03690107]
# Word: quite 	 Log-Prob_forward: -3.700911283493042; Log-Prob_backwards: -2.4273438453674316
#
# ['[CLS]', 'he', 'was', 'receiving', 'quite', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['a', 'the', 'good', 'some', 'his']
# Ordered top predicted values: [0.7040462  0.19572857 0.01332561 0.00994919 0.00927669]
#
# ['[CLS]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', 'ridiculous', 'the', '.', '[SEP]']
# Ordered top predicted tokens: ['.', 'the', ',', 'was', 'how']
# Ordered top predicted values: [0.1974962  0.0918081  0.07135662 0.06644341 0.04478307]
# Word: a 	 Log-Prob_forward: -0.15239885449409485; Log-Prob_backwards: -1.5340116024017334
#
# ['[CLS]', 'he', 'was', 'receiving', 'quite', 'a', '[MASK]', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['good', 'little', 'few', 'bit', 'welcome']
# Ordered top predicted values: [0.14601904 0.07102514 0.0652443  0.06102804 0.04908101]
#
# ['[CLS]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', 'the', '.', '[SEP]']
# Ordered top predicted tokens: ['.', ',', 'is', 'of', 'and']
# Ordered top predicted values: [0.4087829  0.0745782  0.04979466 0.04646596 0.03648136]
# Word: ridiculous 	 Log-Prob_forward: -4.749502182006836; Log-Prob_backwards: -5.729475975036621
#
# ['[CLS]', 'he', 'was', 'receiving', 'quite', 'a', 'ridiculous', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['look', 'lecture', 'reaction', 'response', 'explanation']
# Ordered top predicted values: [0.08539076 0.06090504 0.05876281 0.04826728 0.03506526]
#
# ['[CLS]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '.', '[SEP]']
# Ordered top predicted tokens: ['##ey', '##er', '##e', '##y', '##an']
# Ordered top predicted values: [0.08470336 0.05584621 0.0479612  0.04478891 0.04042916]
# Word: the 	 Log-Prob_forward: -4.417945384979248; Log-Prob_backwards: -4.506618499755859
#
# ['[CLS]', 'he', 'was', 'receiving', 'quite', 'a', 'ridiculous', 'the', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['.', '!', ';', '?', '...']
# Ordered top predicted values: [8.4555572e-01 1.2708381e-01 1.9046243e-02 7.7665029e-03 1.0509691e-04]
#
# ['[CLS]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['.', ';', '!', '?', '"']
# Ordered top predicted values: [9.7217166e-01 1.5479651e-02 9.0014040e-03 2.8689061e-03 1.0739715e-04]
# Word: . 	 Log-Prob_forward: -0.07285776734352112; Log-Prob_backwards: -0.012257042340934277
# Raw forward sentence probability: -21.9938023686409
# Raw backward sentence probability: -20.9078471949324
#
# Average normalized sentence prob: -21.45082478178665
# 3.541401918411717e-22

# %%
get_sentence_prob("penguins are birds.")
get_sentence_prob("penguins have wings.")
get_sentence_prob("wings are useful.")
# Out:
# Processing sentence: ['[CLS]', 'penguins', 'are', 'birds', '.', '[SEP]']
#
#
# ['[CLS]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['the', '"', 'a', 'i', 'no']
# Ordered top predicted values: [0.09850086 0.06786957 0.05361035 0.03242255 0.01996884]
#
# ['[CLS]', '[MASK]', 'are', 'birds', '.', '[SEP]']
# Ordered top predicted tokens: ['there', 'they', 'some', 'these', 'all']
# Ordered top predicted values: [0.50550175 0.17322007 0.05124235 0.04546349 0.01676534]
# Word: penguins 	 Log-Prob_forward: -5.483602046966553; Log-Prob_backwards: -4.805809020996094
#
# ['[CLS]', 'penguins', '[MASK]', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['.', '&', 'illustrated', 'and', 'world']
# Ordered top predicted values: [0.55944806 0.0238416  0.02219316 0.01686097 0.01659434]
#
# ['[CLS]', '[MASK]', '[MASK]', 'birds', '.', '[SEP]']
# Ordered top predicted tokens: ['the', 'of', 'for', '.', 'wild']
# Ordered top predicted values: [0.05914232 0.02854817 0.02677561 0.02595682 0.02240478]
# Word: are 	 Log-Prob_forward: -2.881596565246582; Log-Prob_backwards: -3.3769967555999756
#
# ['[CLS]', 'penguins', 'are', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['common', 'present', 'abundant', 'rare', 'popular']
# Ordered top predicted values: [0.2743478  0.09498348 0.04726823 0.0354636  0.02647407]
#
# ['[CLS]', '[MASK]', '[MASK]', '[MASK]', '.', '[SEP]']
# Ordered top predicted tokens: ['press', 'books', '"', 'p', 'publishing']
# Ordered top predicted values: [0.09253968 0.03637059 0.02992065 0.02453935 0.02047775]
# Word: birds 	 Log-Prob_forward: -4.111104488372803; Log-Prob_backwards: -3.8537800312042236
#
# ['[CLS]', 'penguins', 'are', 'birds', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['.', ';', '?', '!', '|']
# Ordered top predicted values: [8.3594638e-01 1.6363811e-01 2.0536242e-04 1.9307235e-04 1.0964351e-05]
#
# ['[CLS]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['.', '!', ';', '?', '|']
# Ordered top predicted values: [0.8542504  0.06440246 0.04308312 0.03126545 0.00210975]
# Word: . 	 Log-Prob_forward: -0.07782157510519028; Log-Prob_backwards: -0.06841482222080231
# Raw forward sentence probability: -12.554124675691128
# Raw backward sentence probability: -12.105000630021095
#
# Average normalized sentence prob: -12.329562652856112
#
# Processing sentence: ['[CLS]', 'penguins', 'have', 'wings', '.', '[SEP]']
#
#
# ['[CLS]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['the', '"', 'a', 'i', 'no']
# Ordered top predicted values: [0.09850086 0.06786957 0.05361035 0.03242255 0.01996884]
#
# ['[CLS]', '[MASK]', 'have', 'wings', '.', '[SEP]']
# Ordered top predicted tokens: ['they', 'some', 'males', 'adults', 'females']
# Ordered top predicted values: [0.72663254 0.05759723 0.03968828 0.02404685 0.01637915]
# Word: penguins 	 Log-Prob_forward: -5.483602046966553; Log-Prob_backwards: -4.3806233406066895
#
# ['[CLS]', 'penguins', '[MASK]', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['.', '&', 'illustrated', 'and', 'world']
# Ordered top predicted values: [0.55944806 0.0238416  0.02219316 0.01686097 0.01659434]
#
# ['[CLS]', '[MASK]', '[MASK]', 'wings', '.', '[SEP]']
# Ordered top predicted tokens: ['the', 'with', 'my', ',', 'without']
# Ordered top predicted values: [0.07719745 0.06130296 0.05574822 0.05374566 0.0336776 ]
# Word: have 	 Log-Prob_forward: -4.096501350402832; Log-Prob_backwards: -2.15815806388855
#
# ['[CLS]', 'penguins', 'have', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['wings', 'eyes', 'nests', 'escaped', 'sails']
# Ordered top predicted values: [0.10147791 0.02922424 0.02623542 0.02561248 0.02114347]
#
# ['[CLS]', '[MASK]', '[MASK]', '[MASK]', '.', '[SEP]']
# Ordered top predicted tokens: ['press', 'books', '"', 'p', 'publishing']
# Ordered top predicted values: [0.09253968 0.03637059 0.02992065 0.02453935 0.02047775]
# Word: wings 	 Log-Prob_forward: -0.9936285018920898; Log-Prob_backwards: -5.176859378814697
#
# ['[CLS]', 'penguins', 'have', 'wings', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['.', ';', '!', '?', '|']
# Ordered top predicted values: [9.2426836e-01 7.5543821e-02 9.5193849e-05 8.4386724e-05 5.9333079e-06]
#
# ['[CLS]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['.', '!', ';', '?', '|']
# Ordered top predicted values: [0.8542504  0.06440246 0.04308312 0.03126545 0.00210975]
# Word: . 	 Log-Prob_forward: -0.034201912581920624; Log-Prob_backwards: -0.06841482222080231
# Raw forward sentence probability: -10.607933811843395
# Raw backward sentence probability: -11.784055605530739
#
# Average normalized sentence prob: -11.195994708687067
#
# Processing sentence: ['[CLS]', 'wings', 'are', 'useful', '.', '[SEP]']
#
#
# ['[CLS]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['the', '"', 'a', 'i', 'no']
# Ordered top predicted values: [0.09850086 0.06786957 0.05361035 0.03242255 0.01996884]
#
# ['[CLS]', '[MASK]', 'are', 'useful', '.', '[SEP]']
# Ordered top predicted tokens: ['they', 'you', 'these', 'we', 'those']
# Ordered top predicted values: [0.5421818  0.0973146  0.05521332 0.0310561  0.01821809]
# Word: wings 	 Log-Prob_forward: -4.771424770355225; Log-Prob_backwards: -4.244322776794434
#
# ['[CLS]', 'wings', '[MASK]', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['were', 'to', 'and', 'now', 'not']
# Ordered top predicted values: [0.05568396 0.04577586 0.02327493 0.02032858 0.01867087]
#
# ['[CLS]', '[MASK]', '[MASK]', 'useful', '.', '[SEP]']
# Ordered top predicted tokens: ['very', 'was', 'and', 'but', 'is']
# Ordered top predicted values: [0.19987376 0.13774419 0.0816773  0.05750027 0.05395287]
# Word: are 	 Log-Prob_forward: -1.7379571199417114; Log-Prob_backwards: -2.473512649536133
#
# ['[CLS]', 'wings', 'are', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['brown', 'white', 'black', 'grey', 'green']
# Ordered top predicted values: [0.23394062 0.16845371 0.13186584 0.05684345 0.02260858]
#
# ['[CLS]', '[MASK]', '[MASK]', '[MASK]', '.', '[SEP]']
# Ordered top predicted tokens: ['press', 'books', '"', 'p', 'publishing']
# Ordered top predicted values: [0.09253968 0.03637059 0.02992065 0.02453935 0.02047775]
# Word: useful 	 Log-Prob_forward: -5.736351013183594; Log-Prob_backwards: -5.591579914093018
#
# ['[CLS]', 'wings', 'are', 'useful', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['.', ';', '!', '?', '|']
# Ordered top predicted values: [8.1559610e-01 1.8390919e-01 3.1253425e-04 1.4737750e-04 2.0178890e-05]
#
# ['[CLS]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['.', '!', ';', '?', '|']
# Ordered top predicted values: [0.8542504  0.06440246 0.04308312 0.03126545 0.00210975]
# Word: . 	 Log-Prob_forward: -0.08852486312389374; Log-Prob_backwards: -0.06841482222080231
# Raw forward sentence probability: -12.334257766604424
# Raw backward sentence probability: -12.377830162644386
#
# Average normalized sentence prob: -12.356043964624405
# 4.4051026738671185e-13

# %%
get_sentence_prob("The kids eat the candy.")
get_sentence_prob("The kids eat the apple.")
get_sentence_prob("The kids ate the apple.")
get_sentence_prob("The kids ate the apple quickly.")
get_sentence_prob("The kids ate the apple slowly.")
# Out:
# Processing sentence: ['[CLS]', 'the', 'kids', 'eat', 'the', 'candy', '.', '[SEP]']
#
#
# ['[CLS]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['and', '-', '.', '"', '(']
# Ordered top predicted values: [0.02624164 0.02091097 0.01713027 0.01695242 0.01515674]
#
# ['[CLS]', '[MASK]', 'kids', 'eat', 'the', 'candy', '.', '[SEP]']
# Ordered top predicted tokens: ['the', 'other', 'some', 'my', 'little']
# Ordered top predicted values: [0.96681714 0.00511999 0.00450562 0.00371905 0.00316838]
# Word: the 	 Log-Prob_forward: -2.188230037689209; Log-Prob_backwards: -0.014655658043920994
#
# ['[CLS]', 'the', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['weather', 'film', 'score', 'book', 'story']
# Ordered top predicted values: [0.04039879 0.02398504 0.01847865 0.0163132  0.01564541]
#
# ['[CLS]', '[MASK]', '[MASK]', 'eat', 'the', 'candy', '.', '[SEP]']
# Ordered top predicted tokens: ['should', 'will', 'can', 'would', 'just']
# Ordered top predicted values: [0.24648893 0.11865531 0.09942123 0.08236377 0.07354847]
# Word: kids 	 Log-Prob_forward: -4.329418659210205; Log-Prob_backwards: -3.8330960273742676
#
# ['[CLS]', 'the', 'kids', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['were', 'are', 'had', 'have', 'got']
# Ordered top predicted values: [0.45805913 0.18301487 0.03108435 0.01403832 0.01297846]
#
# ['[CLS]', '[MASK]', '[MASK]', '[MASK]', 'the', 'candy', '.', '[SEP]']
# Ordered top predicted tokens: ['took', 'ate', 'wanted', 'got', 'had']
# Ordered top predicted values: [0.16031441 0.07917323 0.04267041 0.03666441 0.03634102]
# Word: eat 	 Log-Prob_forward: -3.2072722911834717; Log-Prob_backwards: -3.3193492889404297
#
# ['[CLS]', 'the', 'kids', 'eat', '[MASK]', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['the', 'their', 'some', 'a', 'good']
# Ordered top predicted values: [0.17813876 0.09766585 0.02662555 0.02386182 0.01848585]
#
# ['[CLS]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', 'candy', '.', '[SEP]']
# Ordered top predicted tokens: ['cotton', 'eye', 'for', 'the', 'like']
# Ordered top predicted values: [0.10498925 0.07246985 0.05321535 0.05037298 0.04307249]
# Word: the 	 Log-Prob_forward: -0.7492415904998779; Log-Prob_backwards: -1.2978023290634155
#
# ['[CLS]', 'the', 'kids', 'eat', 'the', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['food', 'cookies', 'fish', 'cake', 'meat']
# Ordered top predicted values: [0.21703133 0.06858362 0.03243079 0.03112792 0.03046949]
#
# ['[CLS]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '.', '[SEP]']
# Ordered top predicted tokens: ['"', ')', '##n', ']', 'p']
# Ordered top predicted values: [0.12908188 0.05665407 0.0177871  0.01615995 0.00986856]
# Word: candy 	 Log-Prob_forward: -1.549659013748169; Log-Prob_backwards: -5.205572128295898
#
# ['[CLS]', 'the', 'kids', 'eat', 'the', 'candy', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['.', ';', '!', '?', '...']
# Ordered top predicted values: [9.9465430e-01 5.3039673e-03 4.0989671e-05 7.2619940e-07 9.6256709e-09]
#
# ['[CLS]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['.', ';', '|', '!', '?']
# Ordered top predicted values: [0.7197229  0.2446192  0.0246317  0.00498043 0.00401123]
# Word: . 	 Log-Prob_forward: -0.0023278365842998028; Log-Prob_backwards: -0.14283466339111328
# Raw forward sentence probability: -12.026149428915232
# Raw backward sentence probability: -13.813310095109046
#
# Average normalized sentence prob: -12.919729762012139
#
# Processing sentence: ['[CLS]', 'the', 'kids', 'eat', 'the', 'apple', '.', '[SEP]']
#
#
# ['[CLS]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['and', '-', '.', '"', '(']
# Ordered top predicted values: [0.02624164 0.02091097 0.01713027 0.01695242 0.01515674]
#
# ['[CLS]', '[MASK]', 'kids', 'eat', 'the', 'apple', '.', '[SEP]']
# Ordered top predicted tokens: ['the', 'some', 'my', 'little', 'our']
# Ordered top predicted values: [0.9711817  0.0062097  0.0047808  0.00212826 0.00171928]
# Word: the 	 Log-Prob_forward: -2.188230037689209; Log-Prob_backwards: -0.01269951369613409
#
# ['[CLS]', 'the', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['weather', 'film', 'score', 'book', 'story']
# Ordered top predicted values: [0.04039879 0.02398504 0.01847865 0.0163132  0.01564541]
#
# ['[CLS]', '[MASK]', '[MASK]', 'eat', 'the', 'apple', '.', '[SEP]']
# Ordered top predicted tokens: ['should', 'will', ',', 'must', 'can']
# Ordered top predicted values: [0.12886852 0.12368888 0.11053679 0.08938157 0.08525719]
# Word: kids 	 Log-Prob_forward: -4.329418659210205; Log-Prob_backwards: -4.432932376861572
#
# ['[CLS]', 'the', 'kids', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['were', 'are', 'had', 'have', 'got']
# Ordered top predicted values: [0.45805913 0.18301487 0.03108435 0.01403832 0.01297846]
#
# ['[CLS]', '[MASK]', '[MASK]', '[MASK]', 'the', 'apple', '.', '[SEP]']
# Ordered top predicted tokens: ['of', 'at', 'in', 'and', 'on']
# Ordered top predicted values: [0.23147754 0.08573806 0.08245695 0.06939063 0.05840191]
# Word: eat 	 Log-Prob_forward: -3.2072722911834717; Log-Prob_backwards: -3.245680332183838
#
# ['[CLS]', 'the', 'kids', 'eat', '[MASK]', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['the', 'their', 'some', 'a', 'good']
# Ordered top predicted values: [0.17813876 0.09766585 0.02662555 0.02386182 0.01848585]
#
# ['[CLS]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', 'apple', '.', '[SEP]']
# Ordered top predicted tokens: ['the', 'big', 'golden', 'red', 'black']
# Ordered top predicted values: [0.08482028 0.06450091 0.05034276 0.04952531 0.04622569]
# Word: the 	 Log-Prob_forward: -0.7492415904998779; Log-Prob_backwards: -1.071500301361084
#
# ['[CLS]', 'the', 'kids', 'eat', 'the', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['food', 'cookies', 'fish', 'cake', 'meat']
# Ordered top predicted values: [0.21703133 0.06858362 0.03243079 0.03112792 0.03046949]
#
# ['[CLS]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '.', '[SEP]']
# Ordered top predicted tokens: ['"', ')', '##n', ']', 'p']
# Ordered top predicted values: [0.12908188 0.05665407 0.0177871  0.01615995 0.00986856]
# Word: apple 	 Log-Prob_forward: -2.4195590019226074; Log-Prob_backwards: -4.625662803649902
#
# ['[CLS]', 'the', 'kids', 'eat', 'the', 'apple', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['.', ';', '!', '?', '...']
# Ordered top predicted values: [9.9050164e-01 9.4363280e-03 5.6814661e-05 5.1711963e-06 8.0696509e-08]
#
# ['[CLS]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['.', ';', '|', '!', '?']
# Ordered top predicted values: [0.7197229  0.2446192  0.0246317  0.00498043 0.00401123]
# Word: . 	 Log-Prob_forward: -0.004144800361245871; Log-Prob_backwards: -0.14283466339111328
# Raw forward sentence probability: -12.897866380866617
# Raw backward sentence probability: -13.531309991143644
#
# Average normalized sentence prob: -13.21458818600513
#
# Processing sentence: ['[CLS]', 'the', 'kids', 'ate', 'the', 'apple', '.', '[SEP]']
#
#
# ['[CLS]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['and', '-', '.', '"', '(']
# Ordered top predicted values: [0.02624164 0.02091097 0.01713027 0.01695242 0.01515674]
#
# ['[CLS]', '[MASK]', 'kids', 'ate', 'the', 'apple', '.', '[SEP]']
# Ordered top predicted tokens: ['the', 'some', 'two', 'other', 'three']
# Ordered top predicted values: [0.9631896  0.00837886 0.00329488 0.00235934 0.00199647]
# Word: the 	 Log-Prob_forward: -2.188230037689209; Log-Prob_backwards: -0.016288215294480324
#
# ['[CLS]', 'the', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['weather', 'film', 'score', 'book', 'story']
# Ordered top predicted values: [0.04039879 0.02398504 0.01847865 0.0163132  0.01564541]
#
# ['[CLS]', '[MASK]', '[MASK]', 'ate', 'the', 'apple', '.', '[SEP]']
# Ordered top predicted tokens: ['just', 'almost', 'finally', 'never', 'barely']
# Ordered top predicted values: [0.19932558 0.09026665 0.06681699 0.04513903 0.03662128]
# Word: kids 	 Log-Prob_forward: -4.329418659210205; Log-Prob_backwards: -4.218714714050293
#
# ['[CLS]', 'the', 'kids', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['were', 'are', 'had', 'have', 'got']
# Ordered top predicted values: [0.45805913 0.18301487 0.03108435 0.01403832 0.01297846]
#
# ['[CLS]', '[MASK]', '[MASK]', '[MASK]', 'the', 'apple', '.', '[SEP]']
# Ordered top predicted tokens: ['of', 'at', 'in', 'and', 'on']
# Ordered top predicted values: [0.23147754 0.08573806 0.08245695 0.06939063 0.05840191]
# Word: ate 	 Log-Prob_forward: -2.647407054901123; Log-Prob_backwards: -1.8155173063278198
#
# ['[CLS]', 'the', 'kids', 'ate', '[MASK]', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['the', 'their', 'in', 'a', 'at']
# Ordered top predicted values: [0.1605707  0.15663709 0.02839522 0.02668495 0.01951117]
#
# ['[CLS]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', 'apple', '.', '[SEP]']
# Ordered top predicted tokens: ['the', 'big', 'golden', 'red', 'black']
# Ordered top predicted values: [0.08482028 0.06450091 0.05034276 0.04952531 0.04622569]
# Word: the 	 Log-Prob_forward: -0.7943336963653564; Log-Prob_backwards: -1.071500301361084
#
# ['[CLS]', 'the', 'kids', 'ate', 'the', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['food', 'cookies', 'bread', 'cake', 'popcorn']
# Ordered top predicted values: [0.18070029 0.07747439 0.05205146 0.04607956 0.02808118]
#
# ['[CLS]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '.', '[SEP]']
# Ordered top predicted tokens: ['"', ')', '##n', ']', 'p']
# Ordered top predicted values: [0.12908188 0.05665407 0.0177871  0.01615995 0.00986856]
# Word: apple 	 Log-Prob_forward: -2.3370513916015625; Log-Prob_backwards: -4.625662803649902
#
# ['[CLS]', 'the', 'kids', 'ate', 'the', 'apple', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['.', ';', '!', '?', '...']
# Ordered top predicted values: [9.8701048e-01 1.2913065e-02 6.7607667e-05 8.3519872e-06 1.7164463e-07]
#
# ['[CLS]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['.', ';', '|', '!', '?']
# Ordered top predicted values: [0.7197229  0.2446192  0.0246317  0.00498043 0.00401123]
# Word: . 	 Log-Prob_forward: -0.005678236484527588; Log-Prob_backwards: -0.14283466339111328
# Raw forward sentence probability: -12.302119076251984
# Raw backward sentence probability: -11.890518004074693
#
# Average normalized sentence prob: -12.096318540163338
#
# Processing sentence: ['[CLS]', 'the', 'kids', 'ate', 'the', 'apple', 'quickly', '.', '[SEP]']
#
#
# ['[CLS]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['2', '1', 'and', '3', '.']
# Ordered top predicted values: [0.03322905 0.02554637 0.0156561  0.01508306 0.01327825]
#
# ['[CLS]', '[MASK]', 'kids', 'ate', 'the', 'apple', 'quickly', '.', '[SEP]']
# Ordered top predicted tokens: ['the', 'both', 'most', 'some', 'several']
# Ordered top predicted values: [0.96357626 0.02428048 0.00118883 0.00107468 0.00105439]
# Word: the 	 Log-Prob_forward: -2.4191389083862305; Log-Prob_backwards: -0.01611391082406044
#
# ['[CLS]', 'the', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['room', 'man', 'house', 'woman', 'place']
# Ordered top predicted values: [0.0743805  0.02610823 0.02602236 0.01466406 0.01385398]
#
# ['[CLS]', '[MASK]', '[MASK]', 'ate', 'the', 'apple', 'quickly', '.', '[SEP]']
# Ordered top predicted tokens: ['just', '##lia', '##k', '##ra', '##z']
# Ordered top predicted values: [0.18276894 0.0469526  0.04432585 0.04220673 0.03629759]
# Word: kids 	 Log-Prob_forward: -3.523210048675537; Log-Prob_backwards: -4.324633598327637
#
# ['[CLS]', 'the', 'kids', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['were', 'are', 'had', 'got', 'have']
# Ordered top predicted values: [0.40255532 0.2759502  0.04103969 0.03630261 0.03615884]
#
# ['[CLS]', '[MASK]', '[MASK]', '[MASK]', 'the', 'apple', 'quickly', '.', '[SEP]']
# Ordered top predicted tokens: ['on', 'into', 'down', 'off', 'onto']
# Ordered top predicted values: [0.14859977 0.14035788 0.13570766 0.10993999 0.05204179]
# Word: ate 	 Log-Prob_forward: -2.940018892288208; Log-Prob_backwards: -1.542334794998169
#
# ['[CLS]', 'the', 'kids', 'ate', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['the', 'a', 'their', 'at', 'in']
# Ordered top predicted values: [0.13196157 0.06172902 0.05862481 0.05210123 0.05087516]
#
# ['[CLS]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', 'apple', 'quickly', '.', '[SEP]']
# Ordered top predicted tokens: ['the', 'an', 'his', 'another', 'her']
# Ordered top predicted values: [0.6656497  0.18648474 0.05673594 0.02099599 0.00638986]
# Word: the 	 Log-Prob_forward: -0.8795525431632996; Log-Prob_backwards: -0.17675425112247467
#
# ['[CLS]', 'the', 'kids', 'ate', 'the', '[MASK]', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['whole', 'same', 'meat', 'sweet', 'first']
# Ordered top predicted values: [0.11392502 0.04679374 0.02004475 0.01987989 0.01665526]
#
# ['[CLS]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', 'quickly', '.', '[SEP]']
# Ordered top predicted tokens: ['very', 'quite', 'rather', 'pretty', ',']
# Ordered top predicted values: [0.54965305 0.04090169 0.03707093 0.03634892 0.03406526]
# Word: apple 	 Log-Prob_forward: -2.2021851539611816; Log-Prob_backwards: -5.481378078460693
#
# ['[CLS]', 'the', 'kids', 'ate', 'the', 'apple', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['pie', 'together', 'first', 'cake', 'too']
# Ordered top predicted values: [0.14798324 0.12221123 0.04811653 0.04541553 0.04283803]
#
# ['[CLS]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '.', '[SEP]']
# Ordered top predicted tokens: ['##x', '##n', ')', '##2', '##l']
# Ordered top predicted values: [0.02397359 0.0184367  0.01661879 0.01404212 0.01338765]
# Word: quickly 	 Log-Prob_forward: -2.1832308769226074; Log-Prob_backwards: -5.483010292053223
#
# ['[CLS]', 'the', 'kids', 'ate', 'the', 'apple', 'quickly', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['.', ';', '!', '?', '...']
# Ordered top predicted values: [9.89833713e-01 1.01171853e-02 4.63295182e-05 2.28663384e-06
#  1.18913924e-07]
#
# ['[CLS]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['.', ';', '|', '!', '?']
# Ordered top predicted values: [0.6934828  0.25959766 0.03767347 0.00493987 0.00250297]
# Word: . 	 Log-Prob_forward: -0.0044377585873007774; Log-Prob_backwards: -0.15896429121494293
# Raw forward sentence probability: -14.151774181984365
# Raw backward sentence probability: -17.1831892170012
#
# Average normalized sentence prob: -15.667481699492782
#
# Processing sentence: ['[CLS]', 'the', 'kids', 'ate', 'the', 'apple', 'slowly', '.', '[SEP]']
#
#
# ['[CLS]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['2', '1', 'and', '3', '.']
# Ordered top predicted values: [0.03322905 0.02554637 0.0156561  0.01508306 0.01327825]
#
# ['[CLS]', '[MASK]', 'kids', 'ate', 'the', 'apple', 'slowly', '.', '[SEP]']
# Ordered top predicted tokens: ['the', 'both', 'some', 'two', 'most']
# Ordered top predicted values: [0.9715134  0.01455866 0.00127608 0.00125272 0.00112838]
# Word: the 	 Log-Prob_forward: -2.4191389083862305; Log-Prob_backwards: -0.012551208958029747
#
# ['[CLS]', 'the', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['room', 'man', 'house', 'woman', 'place']
# Ordered top predicted values: [0.0743805  0.02610823 0.02602236 0.01466406 0.01385398]
#
# ['[CLS]', '[MASK]', '[MASK]', 'ate', 'the', 'apple', 'slowly', '.', '[SEP]']
# Ordered top predicted tokens: ['##ra', 'just', '##lia', '##tra', '##gan']
# Ordered top predicted values: [0.09196374 0.08772697 0.04690262 0.0303747  0.02774329]
# Word: kids 	 Log-Prob_forward: -3.523210048675537; Log-Prob_backwards: -4.349376678466797
#
# ['[CLS]', 'the', 'kids', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['were', 'are', 'had', 'got', 'have']
# Ordered top predicted values: [0.40255532 0.2759502  0.04103969 0.03630261 0.03615884]
#
# ['[CLS]', '[MASK]', '[MASK]', '[MASK]', 'the', 'apple', 'slowly', '.', '[SEP]']
# Ordered top predicted tokens: ['chewed', 'ate', 'chewing', 'chew', 'took']
# Ordered top predicted values: [0.42848086 0.3529697  0.02675948 0.02048    0.0121783 ]
# Word: ate 	 Log-Prob_forward: -2.940018892288208; Log-Prob_backwards: -0.4522625803947449
#
# ['[CLS]', 'the', 'kids', 'ate', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['the', 'a', 'their', 'at', 'in']
# Ordered top predicted values: [0.13196157 0.06172902 0.05862481 0.05210123 0.05087516]
#
# ['[CLS]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', 'apple', 'slowly', '.', '[SEP]']
# Ordered top predicted tokens: ['the', 'his', 'an', 'her', 'my']
# Ordered top predicted values: [0.6511448  0.1720026  0.10000458 0.04762108 0.01570826]
# Word: the 	 Log-Prob_forward: -0.8795525431632996; Log-Prob_backwards: -0.1863224357366562
#
# ['[CLS]', 'the', 'kids', 'ate', 'the', '[MASK]', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['whole', 'same', 'meat', 'sweet', 'first']
# Ordered top predicted values: [0.11392502 0.04679374 0.02004475 0.01987989 0.01665526]
#
# ['[CLS]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', 'slowly', '.', '[SEP]']
# Ordered top predicted tokens: [',', 'very', 'down', 'away', 'out']
# Ordered top predicted values: [0.4479095  0.24251206 0.06397119 0.03145403 0.02032288]
# Word: apple 	 Log-Prob_forward: -2.2021851539611816; Log-Prob_backwards: -5.784820079803467
#
# ['[CLS]', 'the', 'kids', 'ate', 'the', 'apple', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['pie', 'together', 'first', 'cake', 'too']
# Ordered top predicted values: [0.14798324 0.12221123 0.04811653 0.04541553 0.04283803]
#
# ['[CLS]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '.', '[SEP]']
# Ordered top predicted tokens: ['##x', '##n', ')', '##2', '##l']
# Ordered top predicted values: [0.02397359 0.0184367  0.01661879 0.01404212 0.01338765]
# Word: slowly 	 Log-Prob_forward: -1.591262936592102; Log-Prob_backwards: -5.936598777770996
#
# ['[CLS]', 'the', 'kids', 'ate', 'the', 'apple', 'slowly', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['.', ';', '!', '?', '...']
# Ordered top predicted values: [9.9153179e-01 8.4599601e-03 6.5826662e-06 1.4978579e-06 8.4587938e-08]
#
# ['[CLS]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['.', ';', '|', '!', '?']
# Ordered top predicted values: [0.6934828  0.25959766 0.03767347 0.00493987 0.00250297]
# Word: . 	 Log-Prob_forward: -0.003693357575684786; Log-Prob_backwards: -0.15896429121494293
# Raw forward sentence probability: -13.559061840642244
# Raw backward sentence probability: -16.880896052345634
#
# Average normalized sentence prob: -15.219978946493939
# 6.025887973582306e-16

# %%
get_sentence_prob("The kids eat the candy.")
get_sentence_prob("kids eat.")
get_sentence_prob("eat kids.")
get_sentence_prob("kids eat candy.")
get_sentence_prob("the kids eat.")
get_sentence_prob("small kids eat.")
# Out:
# Processing sentence: ['[CLS]', 'the', 'kids', 'eat', 'the', 'candy', '.', '[SEP]']
#
#
# ['[CLS]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['and', '-', '.', '"', '(']
# Ordered top predicted values: [0.02624164 0.02091097 0.01713027 0.01695242 0.01515674]
#
# ['[CLS]', '[MASK]', 'kids', 'eat', 'the', 'candy', '.', '[SEP]']
# Ordered top predicted tokens: ['the', 'other', 'some', 'my', 'little']
# Ordered top predicted values: [0.96681714 0.00511999 0.00450562 0.00371905 0.00316838]
# Word: the 	 Log-Prob_forward: -2.188230037689209; Log-Prob_backwards: -0.014655658043920994
#
# ['[CLS]', 'the', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['weather', 'film', 'score', 'book', 'story']
# Ordered top predicted values: [0.04039879 0.02398504 0.01847865 0.0163132  0.01564541]
#
# ['[CLS]', '[MASK]', '[MASK]', 'eat', 'the', 'candy', '.', '[SEP]']
# Ordered top predicted tokens: ['should', 'will', 'can', 'would', 'just']
# Ordered top predicted values: [0.24648893 0.11865531 0.09942123 0.08236377 0.07354847]
# Word: kids 	 Log-Prob_forward: -4.329418659210205; Log-Prob_backwards: -3.8330960273742676
#
# ['[CLS]', 'the', 'kids', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['were', 'are', 'had', 'have', 'got']
# Ordered top predicted values: [0.45805913 0.18301487 0.03108435 0.01403832 0.01297846]
#
# ['[CLS]', '[MASK]', '[MASK]', '[MASK]', 'the', 'candy', '.', '[SEP]']
# Ordered top predicted tokens: ['took', 'ate', 'wanted', 'got', 'had']
# Ordered top predicted values: [0.16031441 0.07917323 0.04267041 0.03666441 0.03634102]
# Word: eat 	 Log-Prob_forward: -3.2072722911834717; Log-Prob_backwards: -3.3193492889404297
#
# ['[CLS]', 'the', 'kids', 'eat', '[MASK]', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['the', 'their', 'some', 'a', 'good']
# Ordered top predicted values: [0.17813876 0.09766585 0.02662555 0.02386182 0.01848585]
#
# ['[CLS]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', 'candy', '.', '[SEP]']
# Ordered top predicted tokens: ['cotton', 'eye', 'for', 'the', 'like']
# Ordered top predicted values: [0.10498925 0.07246985 0.05321535 0.05037298 0.04307249]
# Word: the 	 Log-Prob_forward: -0.7492415904998779; Log-Prob_backwards: -1.2978023290634155
#
# ['[CLS]', 'the', 'kids', 'eat', 'the', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['food', 'cookies', 'fish', 'cake', 'meat']
# Ordered top predicted values: [0.21703133 0.06858362 0.03243079 0.03112792 0.03046949]
#
# ['[CLS]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '.', '[SEP]']
# Ordered top predicted tokens: ['"', ')', '##n', ']', 'p']
# Ordered top predicted values: [0.12908188 0.05665407 0.0177871  0.01615995 0.00986856]
# Word: candy 	 Log-Prob_forward: -1.549659013748169; Log-Prob_backwards: -5.205572128295898
#
# ['[CLS]', 'the', 'kids', 'eat', 'the', 'candy', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['.', ';', '!', '?', '...']
# Ordered top predicted values: [9.9465430e-01 5.3039673e-03 4.0989671e-05 7.2619940e-07 9.6256709e-09]
#
# ['[CLS]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['.', ';', '|', '!', '?']
# Ordered top predicted values: [0.7197229  0.2446192  0.0246317  0.00498043 0.00401123]
# Word: . 	 Log-Prob_forward: -0.0023278365842998028; Log-Prob_backwards: -0.14283466339111328
# Raw forward sentence probability: -12.026149428915232
# Raw backward sentence probability: -13.813310095109046
#
# Average normalized sentence prob: -12.919729762012139
#
# Processing sentence: ['[CLS]', 'kids', 'eat', '.', '[SEP]']
#
#
# ['[CLS]', '[MASK]', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['-', '(', 'in', '.', '&']
# Ordered top predicted values: [0.04790248 0.04497821 0.04007062 0.03190231 0.02359308]
#
# ['[CLS]', '[MASK]', 'eat', '.', '[SEP]']
# Ordered top predicted tokens: ['i', 'we', 'and', 'to', 'you']
# Ordered top predicted values: [0.4578031  0.2059562  0.09732728 0.08631539 0.05053893]
# Word: kids 	 Log-Prob_forward: -4.318787097930908; Log-Prob_backwards: -3.679837226867676
#
# ['[CLS]', 'kids', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['play', 'cry', 'lost', 'talk', 'born']
# Ordered top predicted values: [0.05520034 0.03242426 0.03202088 0.01916252 0.01332032]
#
# ['[CLS]', '[MASK]', '[MASK]', '.', '[SEP]']
# Ordered top predicted tokens: ['vol', 'p', 'ed', '##s', '##l']
# Ordered top predicted values: [0.08807144 0.05930213 0.04112209 0.02897006 0.02427902]
# Word: eat 	 Log-Prob_forward: -2.0715839862823486; Log-Prob_backwards: -5.266054153442383
#
# ['[CLS]', 'kids', 'eat', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['.', ';', '!', '|', '?']
# Ordered top predicted values: [9.9647248e-01 3.5254390e-03 2.1495739e-06 3.1515373e-08 2.3499886e-08]
#
# ['[CLS]', '[MASK]', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['.', ';', '|', '!', '?']
# Ordered top predicted values: [9.4962806e-01 4.3981727e-02 3.6494015e-03 1.9981153e-03 5.5857777e-04]
# Word: . 	 Log-Prob_forward: -0.0015346917789429426; Log-Prob_backwards: -0.022446464747190475
# Raw forward sentence probability: -6.3919057759922
# Raw backward sentence probability: -8.968337845057249
#
# Average normalized sentence prob: -7.680121810524724
#
# Processing sentence: ['[CLS]', 'eat', 'kids', '.', '[SEP]']
#
#
# ['[CLS]', '[MASK]', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['-', '(', 'in', '.', '&']
# Ordered top predicted values: [0.04790248 0.04497821 0.04007062 0.03190231 0.02359308]
#
# ['[CLS]', '[MASK]', 'kids', '.', '[SEP]']
# Ordered top predicted tokens: ['no', 'two', 'three', 'the', 'four']
# Ordered top predicted values: [0.6810762  0.07457405 0.04929533 0.03139803 0.02879333]
# Word: eat 	 Log-Prob_forward: -4.364346027374268; Log-Prob_backwards: -5.2054829597473145
#
# ['[CLS]', 'eat', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['up', 'well', 'something', 'it', 'breakfast']
# Ordered top predicted values: [0.18577126 0.17317584 0.07135715 0.06266896 0.0247398 ]
#
# ['[CLS]', '[MASK]', '[MASK]', '.', '[SEP]']
# Ordered top predicted tokens: ['vol', 'p', 'ed', '##s', '##l']
# Ordered top predicted values: [0.08807144 0.05930213 0.04112209 0.02897006 0.02427902]
# Word: kids 	 Log-Prob_forward: -3.7421224117279053; Log-Prob_backwards: -4.752756118774414
#
# ['[CLS]', 'eat', 'kids', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['.', ';', '!', '?', '|']
# Ordered top predicted values: [9.9717158e-01 2.7326304e-03 9.2862079e-05 2.1136809e-06 8.0594219e-07]
#
# ['[CLS]', '[MASK]', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['.', ';', '|', '!', '?']
# Ordered top predicted values: [9.4962806e-01 4.3981727e-02 3.6494015e-03 1.9981153e-03 5.5857777e-04]
# Word: . 	 Log-Prob_forward: -0.0012301072711125016; Log-Prob_backwards: -0.022446464747190475
# Raw forward sentence probability: -8.107698546373285
# Raw backward sentence probability: -9.980685543268919
#
# Average normalized sentence prob: -9.044192044821102
#
# Processing sentence: ['[CLS]', 'kids', 'eat', 'candy', '.', '[SEP]']
#
#
# ['[CLS]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['in', 'and', '"', '[', '(']
# Ordered top predicted values: [0.04898074 0.04841739 0.04020055 0.03066272 0.02607192]
#
# ['[CLS]', '[MASK]', 'eat', 'candy', '.', '[SEP]']
# Ordered top predicted tokens: ['i', 'they', 'kids', 'we', 'people']
# Ordered top predicted values: [0.49063194 0.11720235 0.10550883 0.08084337 0.07197019]
# Word: kids 	 Log-Prob_forward: -4.812612056732178; Log-Prob_backwards: -0.9767111539840698
#
# ['[CLS]', 'kids', '[MASK]', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['are', 'and', 'were', 'get', "'"]
# Ordered top predicted values: [0.16340278 0.10671242 0.10033302 0.06572437 0.05555808]
#
# ['[CLS]', '[MASK]', '[MASK]', 'candy', '.', '[SEP]']
# Ordered top predicted tokens: ['was', 'like', 'liked', 'wanted', 'needed']
# Ordered top predicted values: [0.11804935 0.05842198 0.05412077 0.0521249  0.0447968 ]
# Word: eat 	 Log-Prob_forward: -2.636563777923584; Log-Prob_backwards: -2.262786388397217
#
# ['[CLS]', 'kids', 'eat', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['lunch', 'cookies', 'food', 'breakfast', 'dinner']
# Ordered top predicted values: [0.10489818 0.05997084 0.05156855 0.04797105 0.04338181]
#
# ['[CLS]', '[MASK]', '[MASK]', '[MASK]', '.', '[SEP]']
# Ordered top predicted tokens: ['vol', 'press', 'p', 'j', 'ii']
# Ordered top predicted values: [0.06490542 0.05437048 0.03844456 0.0262519  0.01432491]
# Word: candy 	 Log-Prob_forward: -1.5477046966552734; Log-Prob_backwards: -5.272588729858398
#
# ['[CLS]', 'kids', 'eat', 'candy', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['.', ';', '!', '?', '|']
# Ordered top predicted values: [9.9884027e-01 1.1573723e-03 2.3371590e-06 4.6723546e-08 2.5806515e-10]
#
# ['[CLS]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['.', ';', '|', '?', '!']
# Ordered top predicted values: [9.5748538e-01 4.0964618e-02 1.0687120e-03 2.2205077e-04 2.2124879e-04]
# Word: . 	 Log-Prob_forward: -0.0005039555835537612; Log-Prob_backwards: -0.018867850303649902
# Raw forward sentence probability: -8.997384486894589
# Raw backward sentence probability: -8.530954122543335
#
# Average normalized sentence prob: -8.764169304718962
#
# Processing sentence: ['[CLS]', 'the', 'kids', 'eat', '.', '[SEP]']
#
#
# ['[CLS]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['in', 'and', '"', '[', '(']
# Ordered top predicted values: [0.04898074 0.04841739 0.04020055 0.03066272 0.02607192]
#
# ['[CLS]', '[MASK]', 'kids', 'eat', '.', '[SEP]']
# Ordered top predicted tokens: ['the', 'my', 'our', 'your', 'those']
# Ordered top predicted values: [9.9059463e-01 6.1706882e-03 1.3728230e-03 3.5931382e-04 3.3610791e-04]
# Word: the 	 Log-Prob_forward: -1.7535656690597534; Log-Prob_backwards: -0.004104032646864653
#
# ['[CLS]', 'the', '[MASK]', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['new', 'daily', 'sunday', 'black', 'american']
# Ordered top predicted values: [0.04158681 0.0356557  0.0195489  0.01173447 0.01115536]
#
# ['[CLS]', '[MASK]', '[MASK]', 'eat', '.', '[SEP]']
# Ordered top predicted tokens: ['should', 'could', 'can', 'would', 'will']
# Ordered top predicted values: [0.21347101 0.17893773 0.15247051 0.11996859 0.10230395]
# Word: kids 	 Log-Prob_forward: -4.28954553604126; Log-Prob_backwards: -4.323204517364502
#
# ['[CLS]', 'the', 'kids', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['laughed', 'screamed', 'cried', 'giggled', 'nodded']
# Ordered top predicted values: [0.2648689  0.09851303 0.05760216 0.03756249 0.03192286]
#
# ['[CLS]', '[MASK]', '[MASK]', '[MASK]', '.', '[SEP]']
# Ordered top predicted tokens: ['vol', 'press', 'p', 'j', 'ii']
# Ordered top predicted values: [0.06490542 0.05437048 0.03844456 0.0262519  0.01432491]
# Word: eat 	 Log-Prob_forward: -4.383874416351318; Log-Prob_backwards: -5.199320316314697
#
# ['[CLS]', 'the', 'kids', 'eat', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['.', ';', '!', '?', '|']
# Ordered top predicted values: [9.9830735e-01 1.6902455e-03 2.3043997e-06 6.1388505e-08 2.8892138e-09]
#
# ['[CLS]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['.', ';', '|', '?', '!']
# Ordered top predicted values: [9.5748538e-01 4.0964618e-02 1.0687120e-03 2.2205077e-04 2.2124879e-04]
# Word: . 	 Log-Prob_forward: -0.0007357325521297753; Log-Prob_backwards: -0.018867850303649902
# Raw forward sentence probability: -10.427721354004461
# Raw backward sentence probability: -9.545496716629714
#
# Average normalized sentence prob: -9.986609035317088
#
# Processing sentence: ['[CLS]', 'small', 'kids', 'eat', '.', '[SEP]']
#
#
# ['[CLS]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['in', 'and', '"', '[', '(']
# Ordered top predicted values: [0.04898074 0.04841739 0.04020055 0.03066272 0.02607192]
#
# ['[CLS]', '[MASK]', 'kids', 'eat', '.', '[SEP]']
# Ordered top predicted tokens: ['the', 'my', 'our', 'your', 'those']
# Ordered top predicted values: [9.9059463e-01 6.1706882e-03 1.3728230e-03 3.5931382e-04 3.3610791e-04]
# Word: small 	 Log-Prob_forward: -4.553163051605225; Log-Prob_backwards: -5.504886150360107
#
# ['[CLS]', 'small', '[MASK]', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: [',', '-', '.', 'town', 'and']
# Ordered top predicted values: [0.04446815 0.0433518  0.0411525  0.03691735 0.02549431]
#
# ['[CLS]', '[MASK]', '[MASK]', 'eat', '.', '[SEP]']
# Ordered top predicted tokens: ['should', 'could', 'can', 'would', 'will']
# Ordered top predicted values: [0.21347101 0.17893773 0.15247051 0.11996859 0.10230395]
# Word: kids 	 Log-Prob_forward: -3.680272340774536; Log-Prob_backwards: -4.323204517364502
#
# ['[CLS]', 'small', 'kids', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['play', 'everywhere', 'too', 'sometimes', 'only']
# Ordered top predicted values: [0.04618071 0.03670042 0.0254536  0.02428726 0.02225387]
#
# ['[CLS]', '[MASK]', '[MASK]', '[MASK]', '.', '[SEP]']
# Ordered top predicted tokens: ['vol', 'press', 'p', 'j', 'ii']
# Ordered top predicted values: [0.06490542 0.05437048 0.03844456 0.0262519  0.01432491]
# Word: eat 	 Log-Prob_forward: -2.3423657417297363; Log-Prob_backwards: -5.199320316314697
#
# ['[CLS]', 'small', 'kids', 'eat', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['.', ';', '!', '?', '|']
# Ordered top predicted values: [9.9529135e-01 4.7059497e-03 2.6479383e-06 1.6773465e-07 8.9448884e-09]
#
# ['[CLS]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['.', ';', '|', '?', '!']
# Ordered top predicted values: [9.5748538e-01 4.0964618e-02 1.0687120e-03 2.2205077e-04 2.2124879e-04]
# Word: . 	 Log-Prob_forward: -0.002049769274890423; Log-Prob_backwards: -0.018867850303649902
# Raw forward sentence probability: -10.577850903384387
# Raw backward sentence probability: -15.046278834342957
#
# Average normalized sentence prob: -12.812064868863672
# 1.5414701923956811e-13

# %%
get_sentence_prob("Smurfs eat the ancient nuns ungracefully.")
get_sentence_prob("Smurfs eat ancient the nuns ungracefully.")
get_sentence_prob("eat smurfs the ancient nuns ungracefully.")
get_sentence_prob("Smurfs eat the ancient ungracefully nuns.")
get_sentence_prob("Smurfs the eat ancient nuns ungracefully.")
# Out:
# Processing sentence: ['[CLS]', 'sm', '##ur', '##fs', 'eat', 'the', 'ancient', 'nuns', 'un', '##gra', '##ce', '##fully', '.', '[SEP]']
#
# Word: sm 	 Prob_forward: -8.421839714050293; Prob_backwards: -0.08659450709819794
# Word: ##ur 	 Prob_forward: -3.792858839035034; Prob_backwards: -10.409788131713867
# Word: ##fs 	 Prob_forward: -2.545891523361206; Prob_backwards: -16.56703758239746
# Word: eat 	 Prob_forward: -8.448018074035645; Prob_backwards: -12.25107479095459
# Word: the 	 Prob_forward: -1.7545280456542969; Prob_backwards: -0.23912009596824646
# Word: ancient 	 Prob_forward: -10.828279495239258; Prob_backwards: -9.582014083862305
# Word: nuns 	 Prob_forward: -12.031983375549316; Prob_backwards: -17.856948852539062
# Word: un 	 Prob_forward: -14.874580383300781; Prob_backwards: -0.000980261480435729
# Word: ##gra 	 Prob_forward: -8.647161483764648; Prob_backwards: -3.939512252807617
# Word: ##ce 	 Prob_forward: -4.396315097808838; Prob_backwards: -12.9059476852417
# Word: ##fully 	 Prob_forward: -0.04681474342942238; Prob_backwards: -11.062105178833008
# Word: . 	 Prob_forward: -0.07176832854747772; Prob_backwards: -0.15806877613067627
# Raw forward sentence probability: -75.86003910377622
# Raw backward sentence probability: -95.05919219902717
#
# Average sentence log-prob: -85.45961565140169
#
# Processing sentence: ['[CLS]', 'sm', '##ur', '##fs', 'eat', 'ancient', 'the', 'nuns', 'un', '##gra', '##ce', '##fully', '.', '[SEP]']
#
# Word: sm 	 Prob_forward: -8.421839714050293; Prob_backwards: -0.0304319579154253
# Word: ##ur 	 Prob_forward: -3.792858839035034; Prob_backwards: -5.094578266143799
# Word: ##fs 	 Prob_forward: -2.545891523361206; Prob_backwards: -13.953265190124512
# Word: eat 	 Prob_forward: -8.448018074035645; Prob_backwards: -12.323060989379883
# Word: ancient 	 Prob_forward: -9.721586227416992; Prob_backwards: -14.834153175354004
# Word: the 	 Prob_forward: -10.654952049255371; Prob_backwards: -0.09726636111736298
# Word: nuns 	 Prob_forward: -13.081194877624512; Prob_backwards: -17.856948852539062
# Word: un 	 Prob_forward: -14.348371505737305; Prob_backwards: -0.000980261480435729
# Word: ##gra 	 Prob_forward: -9.294382095336914; Prob_backwards: -3.939512252807617
# Word: ##ce 	 Prob_forward: -3.4343044757843018; Prob_backwards: -12.9059476852417
# Word: ##fully 	 Prob_forward: -0.059984877705574036; Prob_backwards: -11.062105178833008
# Word: . 	 Prob_forward: -0.07296466827392578; Prob_backwards: -0.15806877613067627
# Raw forward sentence probability: -83.87634892761707
# Raw backward sentence probability: -92.25631894706748
#
# Average sentence log-prob: -88.06633393734228
#
# Processing sentence: ['[CLS]', 'eat', 'sm', '##ur', '##fs', 'the', 'ancient', 'nuns', 'un', '##gra', '##ce', '##fully', '.', '[SEP]']
#
# Word: eat 	 Prob_forward: -11.611237525939941; Prob_backwards: -13.141724586486816
# Word: sm 	 Prob_forward: -11.369266510009766; Prob_backwards: -0.9626296758651733
# Word: ##ur 	 Prob_forward: -1.5907785892486572; Prob_backwards: -10.462422370910645
# Word: ##fs 	 Prob_forward: -2.2179927825927734; Prob_backwards: -17.556398391723633
# Word: the 	 Prob_forward: -6.270805358886719; Prob_backwards: -0.23912009596824646
# Word: ancient 	 Prob_forward: -8.925925254821777; Prob_backwards: -9.582014083862305
# Word: nuns 	 Prob_forward: -12.99796199798584; Prob_backwards: -17.856948852539062
# Word: un 	 Prob_forward: -11.800105094909668; Prob_backwards: -0.000980261480435729
# Word: ##gra 	 Prob_forward: -8.671616554260254; Prob_backwards: -3.939512252807617
# Word: ##ce 	 Prob_forward: -2.9313902854919434; Prob_backwards: -12.9059476852417
# Word: ##fully 	 Prob_forward: -2.293067455291748; Prob_backwards: -11.062105178833008
# Word: . 	 Prob_forward: -0.1992189735174179; Prob_backwards: -0.15806877613067627
# Raw forward sentence probability: -80.8793663829565
# Raw backward sentence probability: -97.86787221184932
#
# Average sentence log-prob: -89.37361929740291
#
# Processing sentence: ['[CLS]', 'sm', '##ur', '##fs', 'eat', 'the', 'ancient', 'un', '##gra', '##ce', '##fully', 'nuns', '.', '[SEP]']
#
# Word: sm 	 Prob_forward: -8.421839714050293; Prob_backwards: -0.0674087405204773
# Word: ##ur 	 Prob_forward: -3.792858839035034; Prob_backwards: -9.22286319732666
# Word: ##fs 	 Prob_forward: -2.545891523361206; Prob_backwards: -15.781919479370117
# Word: eat 	 Prob_forward: -8.448018074035645; Prob_backwards: -10.143357276916504
# Word: the 	 Prob_forward: -1.7545280456542969; Prob_backwards: -0.9263049364089966
# Word: ancient 	 Prob_forward: -10.828279495239258; Prob_backwards: -13.563017845153809
# Word: un 	 Prob_forward: -10.496597290039062; Prob_backwards: -0.0008692346164025366
# Word: ##gra 	 Prob_forward: -7.407825469970703; Prob_backwards: -4.254502296447754
# Word: ##ce 	 Prob_forward: -6.306626796722412; Prob_backwards: -11.839587211608887
# Word: ##fully 	 Prob_forward: -3.8928792476654053; Prob_backwards: -14.384912490844727
# Word: nuns 	 Prob_forward: -13.457612037658691; Prob_backwards: -13.5078125
# Word: . 	 Prob_forward: -0.1467513144016266; Prob_backwards: -0.15806877613067627
# Raw forward sentence probability: -77.49970784783363
# Raw backward sentence probability: -93.85062398534501
#
# Average sentence log-prob: -85.67516591658932
#
# Processing sentence: ['[CLS]', 'sm', '##ur', '##fs', 'the', 'eat', 'ancient', 'nuns', 'un', '##gra', '##ce', '##fully', '.', '[SEP]']
#
# Word: sm 	 Prob_forward: -8.421839714050293; Prob_backwards: -0.7624698877334595
# Word: ##ur 	 Prob_forward: -3.792858839035034; Prob_backwards: -10.782777786254883
# Word: ##fs 	 Prob_forward: -2.545891523361206; Prob_backwards: -16.339839935302734
# Word: the 	 Prob_forward: -4.292987823486328; Prob_backwards: -7.765404224395752
# Word: eat 	 Prob_forward: -10.228960037231445; Prob_backwards: -14.8766450881958
# Word: ancient 	 Prob_forward: -12.220443725585938; Prob_backwards: -9.582014083862305
# Word: nuns 	 Prob_forward: -11.032546997070312; Prob_backwards: -17.856948852539062
# Word: un 	 Prob_forward: -8.594636917114258; Prob_backwards: -0.000980261480435729
# Word: ##gra 	 Prob_forward: -9.179137229919434; Prob_backwards: -3.939512252807617
# Word: ##ce 	 Prob_forward: -4.012724876403809; Prob_backwards: -12.9059476852417
# Word: ##fully 	 Prob_forward: -2.1962413787841797; Prob_backwards: -11.062105178833008
# Word: . 	 Prob_forward: -0.7256648540496826; Prob_backwards: -0.15806877613067627
# Raw forward sentence probability: -77.24393391609192
# Raw backward sentence probability: -106.03271401277743
#
# Average sentence log-prob: -91.63832396443468
# -91.63832396443468

# %%
get_sentence_prob("kids eat the red grapes quickly.")
get_sentence_prob("quickly eat the red grapes kids.")
get_sentence_prob("the kids eat the red grapes quickly.")
get_sentence_prob("girls eat the red grapes quickly.")
get_sentence_prob("the red grapes eat kids quickly.")
get_sentence_prob("kids eat red the grapes quickly.")
get_sentence_prob("eat kids the red grapes quickly.")
get_sentence_prob("kids eat the red quickly grapes.")
get_sentence_prob("kids the eat red grapes quickly.")
# Out:
# Processing sentence: ['[CLS]', 'kids', 'eat', 'the', 'red', 'grapes', 'quickly', '.', '[SEP]']
#
# Word: kids 	 Prob_forward: -9.770715713500977; Prob_backwards: -12.24870777130127
# Word: eat 	 Prob_forward: -8.85970401763916; Prob_backwards: -4.724191188812256
# Word: the 	 Prob_forward: -2.024585723876953; Prob_backwards: -0.48318010568618774
# Word: red 	 Prob_forward: -5.991503715515137; Prob_backwards: -5.627716541290283
# Word: grapes 	 Prob_forward: -9.902673721313477; Prob_backwards: -14.482468605041504
# Word: quickly 	 Prob_forward: -6.720923900604248; Prob_backwards: -12.625097274780273
# Word: . 	 Prob_forward: -0.01455748826265335; Prob_backwards: -0.3660288155078888
# Raw forward sentence probability: -43.284664280712605
# Raw backward sentence probability: -50.55739030241966
#
# Average sentence log-prob: -46.92102729156613
#
# Processing sentence: ['[CLS]', 'quickly', 'eat', 'the', 'red', 'grapes', 'kids', '.', '[SEP]']
#
# Word: quickly 	 Prob_forward: -11.486865043640137; Prob_backwards: -11.558196067810059
# Word: eat 	 Prob_forward: -11.959293365478516; Prob_backwards: -8.01545238494873
# Word: the 	 Prob_forward: -1.855423092842102; Prob_backwards: -3.4601569175720215
# Word: red 	 Prob_forward: -4.598945617675781; Prob_backwards: -3.9300074577331543
# Word: grapes 	 Prob_forward: -8.885632514953613; Prob_backwards: -16.72442626953125
# Word: kids 	 Prob_forward: -12.729324340820312; Prob_backwards: -7.848457336425781
# Word: . 	 Prob_forward: -0.20840224623680115; Prob_backwards: -0.3660288155078888
# Raw forward sentence probability: -51.72388622164726
# Raw backward sentence probability: -51.902725249528885
#
# Average sentence log-prob: -51.813305735588074
#
# Processing sentence: ['[CLS]', 'the', 'kids', 'eat', 'the', 'red', 'grapes', 'quickly', '.', '[SEP]']
#
# Word: the 	 Prob_forward: -5.768765449523926; Prob_backwards: -0.020473014563322067
# Word: kids 	 Prob_forward: -8.245031356811523; Prob_backwards: -9.524877548217773
# Word: eat 	 Prob_forward: -10.747272491455078; Prob_backwards: -7.497977256774902
# Word: the 	 Prob_forward: -1.5610218048095703; Prob_backwards: -0.627249538898468
# Word: red 	 Prob_forward: -6.209031105041504; Prob_backwards: -5.7123823165893555
# Word: grapes 	 Prob_forward: -9.535797119140625; Prob_backwards: -14.851716995239258
# Word: quickly 	 Prob_forward: -5.528532981872559; Prob_backwards: -11.732436180114746
# Word: . 	 Prob_forward: -0.009871107526123524; Prob_backwards: -0.3001890182495117
# Raw forward sentence probability: -47.60532341618091
# Raw backward sentence probability: -50.26730186864734
#
# Average sentence log-prob: -48.93631264241412
#
# Processing sentence: ['[CLS]', 'girls', 'eat', 'the', 'red', 'grapes', 'quickly', '.', '[SEP]']
#
# Word: girls 	 Prob_forward: -9.694291114807129; Prob_backwards: -10.550896644592285
# Word: eat 	 Prob_forward: -9.033809661865234; Prob_backwards: -4.724191188812256
# Word: the 	 Prob_forward: -2.8291404247283936; Prob_backwards: -0.48318010568618774
# Word: red 	 Prob_forward: -5.589519023895264; Prob_backwards: -5.627716541290283
# Word: grapes 	 Prob_forward: -9.485286712646484; Prob_backwards: -14.482468605041504
# Word: quickly 	 Prob_forward: -6.696870803833008; Prob_backwards: -12.625097274780273
# Word: . 	 Prob_forward: -0.026495957747101784; Prob_backwards: -0.3660288155078888
# Raw forward sentence probability: -43.355413699522614
# Raw backward sentence probability: -48.85957917571068
#
# Average sentence log-prob: -46.107496437616646
#
# Processing sentence: ['[CLS]', 'the', 'red', 'grapes', 'eat', 'kids', 'quickly', '.', '[SEP]']
#
# Word: the 	 Prob_forward: -5.570272922515869; Prob_backwards: -0.29326924681663513
# Word: red 	 Prob_forward: -8.689350128173828; Prob_backwards: -3.8750200271606445
# Word: grapes 	 Prob_forward: -10.050687789916992; Prob_backwards: -15.71767520904541
# Word: eat 	 Prob_forward: -6.946560859680176; Prob_backwards: -15.025247573852539
# Word: kids 	 Prob_forward: -11.142003059387207; Prob_backwards: -12.948124885559082
# Word: quickly 	 Prob_forward: -8.758378028869629; Prob_backwards: -12.625097274780273
# Word: . 	 Prob_forward: -0.008404004387557507; Prob_backwards: -0.3660288155078888
# Raw forward sentence probability: -51.16565679293126
# Raw backward sentence probability: -60.85046303272247
#
# Average sentence log-prob: -56.008059912826866
#
# Processing sentence: ['[CLS]', 'kids', 'eat', 'red', 'the', 'grapes', 'quickly', '.', '[SEP]']
#
# Word: kids 	 Prob_forward: -9.770715713500977; Prob_backwards: -9.80723762512207
# Word: eat 	 Prob_forward: -8.85970401763916; Prob_backwards: -4.594557762145996
# Word: red 	 Prob_forward: -7.255248069763184; Prob_backwards: -10.424359321594238
# Word: the 	 Prob_forward: -7.185216426849365; Prob_backwards: -0.39755135774612427
# Word: grapes 	 Prob_forward: -10.154133796691895; Prob_backwards: -14.482468605041504
# Word: quickly 	 Prob_forward: -8.758773803710938; Prob_backwards: -12.625097274780273
# Word: . 	 Prob_forward: -0.015437839552760124; Prob_backwards: -0.3660288155078888
# Raw forward sentence probability: -51.99922966770828
# Raw backward sentence probability: -52.697300761938095
#
# Average sentence log-prob: -52.348265214823186
#
# Processing sentence: ['[CLS]', 'eat', 'kids', 'the', 'red', 'grapes', 'quickly', '.', '[SEP]']
#
# Word: eat 	 Prob_forward: -12.203282356262207; Prob_backwards: -8.310039520263672
# Word: kids 	 Prob_forward: -7.733448505401611; Prob_backwards: -14.306421279907227
# Word: the 	 Prob_forward: -9.909550666809082; Prob_backwards: -0.48318010568618774
# Word: red 	 Prob_forward: -9.571806907653809; Prob_backwards: -5.627716541290283
# Word: grapes 	 Prob_forward: -8.799673080444336; Prob_backwards: -14.482468605041504
# Word: quickly 	 Prob_forward: -7.901790142059326; Prob_backwards: -12.625097274780273
# Word: . 	 Prob_forward: -0.028954586014151573; Prob_backwards: -0.3660288155078888
# Raw forward sentence probability: -56.14850624464452
# Raw backward sentence probability: -56.200952142477036
#
# Average sentence log-prob: -56.17472919356078
#
# Processing sentence: ['[CLS]', 'kids', 'eat', 'the', 'red', 'quickly', 'grapes', '.', '[SEP]']
#
# Word: kids 	 Prob_forward: -9.770715713500977; Prob_backwards: -9.89919662475586
# Word: eat 	 Prob_forward: -8.85970401763916; Prob_backwards: -12.296819686889648
# Word: the 	 Prob_forward: -2.024585723876953; Prob_backwards: -4.121438980102539
# Word: red 	 Prob_forward: -5.991503715515137; Prob_backwards: -9.312590599060059
# Word: quickly 	 Prob_forward: -13.250264167785645; Prob_backwards: -12.451397895812988
# Word: grapes 	 Prob_forward: -16.524660110473633; Prob_backwards: -12.617769241333008
# Word: . 	 Prob_forward: -0.017467232421040535; Prob_backwards: -0.3660288155078888
# Raw forward sentence probability: -56.438900681212544
# Raw backward sentence probability: -61.06524184346199
#
# Average sentence log-prob: -58.75207126233727
#
# Processing sentence: ['[CLS]', 'kids', 'the', 'eat', 'red', 'grapes', 'quickly', '.', '[SEP]']
#
# Word: kids 	 Prob_forward: -9.770715713500977; Prob_backwards: -10.915548324584961
# Word: the 	 Prob_forward: -7.822926998138428; Prob_backwards: -9.635924339294434
# Word: eat 	 Prob_forward: -10.173979759216309; Prob_backwards: -11.458847045898438
# Word: red 	 Prob_forward: -8.437793731689453; Prob_backwards: -5.627716541290283
# Word: grapes 	 Prob_forward: -8.13674259185791; Prob_backwards: -14.482468605041504
# Word: quickly 	 Prob_forward: -6.892327785491943; Prob_backwards: -12.625097274780273
# Word: . 	 Prob_forward: -0.032106973230838776; Prob_backwards: -0.3660288155078888
# Raw forward sentence probability: -51.26659355312586
# Raw backward sentence probability: -65.11163094639778
#
# Average sentence log-prob: -58.18911224976182
# -58.18911224976182

# %%
get_sentence_prob("Colorless green ideas sleep furiously.")
get_sentence_prob("Confused dumb benches eat endlessly.")
get_sentence_prob("Hairless ugly men complain constantly.")
# Out:
# Processing sentence: ['[CLS]', 'color', '##less', 'green', 'ideas', 'sleep', 'furiously', '.', '[SEP]']
#
# Word: color 	 Prob_forward: -10.544276237487793; Prob_backwards: -2.5439460277557373
# Word: ##less 	 Prob_forward: -7.516035079956055; Prob_backwards: -8.04877758026123
# Word: green 	 Prob_forward: -6.6411590576171875; Prob_backwards: -8.82697582244873
# Word: ideas 	 Prob_forward: -12.467616081237793; Prob_backwards: -13.871207237243652
# Word: sleep 	 Prob_forward: -9.88399887084961; Prob_backwards: -12.250245094299316
# Word: furiously 	 Prob_forward: -9.00595474243164; Prob_backwards: -12.923095703125
# Word: . 	 Prob_forward: -0.019949400797486305; Prob_backwards: -0.3660288155078888
# Raw forward sentence probability: -56.078989470377564
# Raw backward sentence probability: -58.830276280641556
#
# Average sentence log-prob: -57.45463287550956
#
# Processing sentence: ['[CLS]', 'confused', 'dumb', 'benches', 'eat', 'endless', '##ly', '.', '[SEP]']
#
# Word: confused 	 Prob_forward: -12.813743591308594; Prob_backwards: -13.935309410095215
# Word: dumb 	 Prob_forward: -11.752983093261719; Prob_backwards: -14.663588523864746
# Word: benches 	 Prob_forward: -18.132976531982422; Prob_backwards: -15.584624290466309
# Word: eat 	 Prob_forward: -8.799528121948242; Prob_backwards: -14.16914176940918
# Word: endless 	 Prob_forward: -7.97768497467041; Prob_backwards: -7.6633687019348145
# Word: ##ly 	 Prob_forward: -0.7332441806793213; Prob_backwards: -7.171707630157471
# Word: . 	 Prob_forward: -0.0732741430401802; Prob_backwards: -0.3660288155078888
# Raw forward sentence probability: -60.28343463689089
# Raw backward sentence probability: -73.55376914143562
#
# Average sentence log-prob: -66.91860188916326
#
# Processing sentence: ['[CLS]', 'hair', '##less', 'ugly', 'men', 'complain', 'constantly', '.', '[SEP]']
#
# Word: hair 	 Prob_forward: -12.474600791931152; Prob_backwards: -1.779586911201477
# Word: ##less 	 Prob_forward: -5.122800350189209; Prob_backwards: -10.748332023620605
# Word: ugly 	 Prob_forward: -10.430011749267578; Prob_backwards: -10.051627159118652
# Word: men 	 Prob_forward: -4.835695743560791; Prob_backwards: -11.358868598937988
# Word: complain 	 Prob_forward: -11.895339012145996; Prob_backwards: -11.254167556762695
# Word: constantly 	 Prob_forward: -1.7756268978118896; Prob_backwards: -13.644427299499512
# Word: . 	 Prob_forward: -0.016684850677847862; Prob_backwards: -0.3660288155078888
# Raw forward sentence probability: -46.550759395584464
# Raw backward sentence probability: -59.20303836464882
#
# Average sentence log-prob: -52.87689888011664
# -52.87689888011664

# %%
get_sentence_prob("The test was a success.")
get_sentence_prob("The was test a success.")
get_sentence_prob("The test was success a.")
get_sentence_prob("The party was a success.")
get_sentence_prob("The farewell party was definitely not a success.")
# Out:
# Processing sentence: ['[CLS]', 'the', 'test', 'was', 'a', 'success', '.', '[SEP]']
#
# Word: the 	 Prob_forward: -5.038585662841797; Prob_backwards: -0.0418301522731781
# Word: test 	 Prob_forward: -9.275725364685059; Prob_backwards: -5.530876636505127
# Word: was 	 Prob_forward: -1.194662094116211; Prob_backwards: -0.10143725574016571
# Word: a 	 Prob_forward: -5.843591213226318; Prob_backwards: -1.1096673011779785
# Word: success 	 Prob_forward: -0.662120521068573; Prob_backwards: -10.63667106628418
# Word: . 	 Prob_forward: -0.05630144849419594; Prob_backwards: -0.3288889527320862
# Raw forward sentence probability: -22.070986304432154
# Raw backward sentence probability: -17.749371364712715
#
# Average sentence log-prob: -19.910178834572434
#
# Processing sentence: ['[CLS]', 'the', 'was', 'test', 'a', 'success', '.', '[SEP]']
#
# Word: the 	 Prob_forward: -5.038585662841797; Prob_backwards: -8.694866180419922
# Word: was 	 Prob_forward: -11.56971263885498; Prob_backwards: -0.7991001009941101
# Word: test 	 Prob_forward: -13.270352363586426; Prob_backwards: -12.136092185974121
# Word: a 	 Prob_forward: -6.2024078369140625; Prob_backwards: -1.1096673011779785
# Word: success 	 Prob_forward: -3.4117355346679688; Prob_backwards: -10.63667106628418
# Word: . 	 Prob_forward: -0.07401980459690094; Prob_backwards: -0.3288889527320862
# Raw forward sentence probability: -39.566813841462135
# Raw backward sentence probability: -33.7052857875824
#
# Average sentence log-prob: -36.636049814522266
#
# Processing sentence: ['[CLS]', 'the', 'test', 'was', 'success', 'a', '.', '[SEP]']
#
# Word: the 	 Prob_forward: -5.038585662841797; Prob_backwards: -0.232442244887352
# Word: test 	 Prob_forward: -9.275725364685059; Prob_backwards: -7.472322940826416
# Word: was 	 Prob_forward: -1.194662094116211; Prob_backwards: -6.317474842071533
# Word: success 	 Prob_forward: -10.774112701416016; Prob_backwards: -16.199316024780273
# Word: a 	 Prob_forward: -9.631125450134277; Prob_backwards: -6.869576454162598
# Word: . 	 Prob_forward: -0.2882668375968933; Prob_backwards: -0.3288889527320862
# Raw forward sentence probability: -36.20247811079025
# Raw backward sentence probability: -37.42002145946026
#
# Average sentence log-prob: -36.811249785125256
#
# Processing sentence: ['[CLS]', 'the', 'party', 'was', 'a', 'success', '.', '[SEP]']
#
# Word: the 	 Prob_forward: -5.038585662841797; Prob_backwards: -0.05855056643486023
# Word: party 	 Prob_forward: -6.54331111907959; Prob_backwards: -5.181707382202148
# Word: was 	 Prob_forward: -2.8780879974365234; Prob_backwards: -0.10143725574016571
# Word: a 	 Prob_forward: -7.668673992156982; Prob_backwards: -1.1096673011779785
# Word: success 	 Prob_forward: -0.7602506875991821; Prob_backwards: -10.63667106628418
# Word: . 	 Prob_forward: -0.0482170507311821; Prob_backwards: -0.3288889527320862
# Raw forward sentence probability: -22.937126509845257
# Raw backward sentence probability: -17.41692252457142
#
# Average sentence log-prob: -20.177024517208338
#
# Processing sentence: ['[CLS]', 'the', 'farewell', 'party', 'was', 'definitely', 'not', 'a', 'success', '.', '[SEP]']
#
# Word: the 	 Prob_forward: -5.532560348510742; Prob_backwards: -0.17559587955474854
# Word: farewell 	 Prob_forward: -12.2467622756958; Prob_backwards: -6.933331489562988
# Word: party 	 Prob_forward: -4.740692615509033; Prob_backwards: -4.864899635314941
# Word: was 	 Prob_forward: -0.2544286549091339; Prob_backwards: -0.09543892741203308
# Word: definitely 	 Prob_forward: -12.213384628295898; Prob_backwards: -13.356999397277832
# Word: not 	 Prob_forward: -3.282292604446411; Prob_backwards: -4.134335041046143
# Word: a 	 Prob_forward: -2.196603775024414; Prob_backwards: -3.981504440307617
# Word: success 	 Prob_forward: -2.1036040782928467; Prob_backwards: -10.10867977142334
# Word: . 	 Prob_forward: -0.023075740784406662; Prob_backwards: -0.2594987154006958
# Raw forward sentence probability: -42.59340472146869
# Raw backward sentence probability: -43.91028329730034
#
# Average sentence log-prob: -43.25184400938451
# -43.25184400938451

# %%
get_sentence_prob("He answered unequivocally.")
get_sentence_prob("He answered quickly.", verbose=True)
# Out:
# Processing sentence: ['[CLS]', 'he', 'answered', 'une', '##qui', '##vo', '##cal', '##ly', '.', '[SEP]']
#
# Word: he 	 Prob_forward: -7.592045307159424; Prob_backwards: -1.267844796180725
# Word: answered 	 Prob_forward: -8.141104698181152; Prob_backwards: -4.511857986450195
# Word: une 	 Prob_forward: -15.309880256652832; Prob_backwards: -0.0012949742376804352
# Word: ##qui 	 Prob_forward: -7.458912372589111; Prob_backwards: -7.119812965393066
# Word: ##vo 	 Prob_forward: -2.9886157512664795; Prob_backwards: -12.645088195800781
# Word: ##cal 	 Prob_forward: -7.105126132955775e-05; Prob_backwards: -10.53508186340332
# Word: ##ly 	 Prob_forward: -0.001719282940030098; Prob_backwards: -6.816740036010742
# Word: . 	 Prob_forward: -0.0001833010755944997; Prob_backwards: -0.3001890182495117
# Raw forward sentence probability: -41.49253202112595
# Raw backward sentence probability: -43.19790983572602
#
# Average sentence log-prob: -42.34522092842599
#
# Processing sentence: ['[CLS]', 'he', 'answered', 'quickly', '.', '[SEP]']
#
#
# ['[CLS]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['in', 'and', '"', '[', '(']
# Ordered top predicted values: [0.04898074 0.04841739 0.04020055 0.03066272 0.02607192]
#
# ['[CLS]', '[MASK]', 'answered', 'quickly', '.', '[SEP]']
# Ordered top predicted tokens: ['i', 'she', 'he', 'jack', 'nick']
# Ordered top predicted values: [0.2943303  0.2310972  0.21517508 0.00285249 0.00283264]
# Word: he 	 Prob_forward: -6.722315788269043; Prob_backwards: -1.5363032817840576
#
# ['[CLS]', 'he', '[MASK]', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['was', 'looked', 'asked', 'said', 'is']
# Ordered top predicted values: [0.4028537  0.05901183 0.05432703 0.04291577 0.03971536]
#
# ['[CLS]', '[MASK]', '[MASK]', 'quickly', '.', '[SEP]']
# Ordered top predicted tokens: ['asked', 'said', 'thought', 'nodded', 'blinked']
# Ordered top predicted values: [0.2587772  0.1465675  0.12193974 0.08968459 0.04111334]
# Word: answered 	 Prob_forward: -5.7055439949035645; Prob_backwards: -4.114648342132568
#
# ['[CLS]', 'he', 'answered', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['it', 'immediately', 'quickly', 'her', 'quietly']
# Ordered top predicted values: [0.3002007  0.1476826  0.06010275 0.03919926 0.03147311]
#
# ['[CLS]', '[MASK]', '[MASK]', '[MASK]', '.', '[SEP]']
# Ordered top predicted tokens: ['vol', 'press', 'p', 'j', 'ii']
# Ordered top predicted values: [0.06490542 0.05437048 0.03844456 0.0262519  0.01432491]
# Word: quickly 	 Prob_forward: -2.811699628829956; Prob_backwards: -13.41380500793457
#
# ['[CLS]', 'he', 'answered', 'quickly', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['.', ';', '!', '?', '...']
# Ordered top predicted values: [9.9814069e-01 1.8559413e-03 2.1156122e-06 1.1307502e-06 6.6726315e-08]
#
# ['[CLS]', '[MASK]', '[MASK]', '[MASK]', '[MASK]', '[SEP]']
# Ordered top predicted tokens: ['.', ';', '|', '?', '!']
# Ordered top predicted values: [9.5748538e-01 4.0964618e-02 1.0687120e-03 2.2205077e-04 2.2124879e-04]
# Word: . 	 Prob_forward: -0.0018610379192978144; Prob_backwards: -0.04344483092427254
# Raw forward sentence probability: -15.241420449921861
# Raw backward sentence probability: -19.10820146277547
#
# Average sentence log-prob: -17.174810956348665
# -17.174810956348665

# %%
get_sentence_prob("The guy with small hands demanded a quid pro quo.")
get_sentence_prob("The guy with small hands demanded an exchange.")
# Out:
# Processing sentence: ['[CLS]', 'the', 'guy', 'with', 'small', 'hands', 'demanded', 'a', 'qui', '##d', 'pro', 'quo', '.', '[SEP]']
#
# Word: the 	 Prob_forward: -3.906177520751953; Prob_backwards: -0.3941221237182617
# Word: guy 	 Prob_forward: -9.926000595092773; Prob_backwards: -7.368597984313965
# Word: with 	 Prob_forward: -7.264544486999512; Prob_backwards: -2.7467923164367676
# Word: small 	 Prob_forward: -9.92628002166748; Prob_backwards: -4.824505805969238
# Word: hands 	 Prob_forward: -6.550938129425049; Prob_backwards: -9.48993968963623
# Word: demanded 	 Prob_forward: -12.739509582519531; Prob_backwards: -15.551085472106934
# Word: a 	 Prob_forward: -7.67767858505249; Prob_backwards: -2.757371664047241
# Word: qui 	 Prob_forward: -12.464286804199219; Prob_backwards: -0.6459168195724487
# Word: ##d 	 Prob_forward: -1.456640601158142; Prob_backwards: -14.112207412719727
# Word: pro 	 Prob_forward: -10.183714866638184; Prob_backwards: -5.321247577667236
# Word: quo 	 Prob_forward: -0.0010539480717852712; Prob_backwards: -14.234658241271973
# Word: . 	 Prob_forward: -0.015031875111162663; Prob_backwards: -0.15806877613067627
# Raw forward sentence probability: -82.11185701668728
# Raw backward sentence probability: -77.6045138835907
#
# Average sentence log-prob: -79.85818545013899
#
# Processing sentence: ['[CLS]', 'the', 'guy', 'with', 'small', 'hands', 'demanded', 'an', 'exchange', '.', '[SEP]']
#
# Word: the 	 Prob_forward: -5.532560348510742; Prob_backwards: -0.3623291850090027
# Word: guy 	 Prob_forward: -8.344962120056152; Prob_backwards: -7.484039306640625
# Word: with 	 Prob_forward: -5.200098037719727; Prob_backwards: -2.0137078762054443
# Word: small 	 Prob_forward: -13.006707191467285; Prob_backwards: -4.948693752288818
# Word: hands 	 Prob_forward: -2.0624802112579346; Prob_backwards: -9.70581340789795
# Word: demanded 	 Prob_forward: -8.102654457092285; Prob_backwards: -8.547494888305664
# Word: an 	 Prob_forward: -7.148486137390137; Prob_backwards: -5.4437103271484375
# Word: exchange 	 Prob_forward: -5.681495666503906; Prob_backwards: -10.658400535583496
# Word: . 	 Prob_forward: -0.003914078697562218; Prob_backwards: -0.2594987154006958
# Raw forward sentence probability: -55.08335824869573
# Raw backward sentence probability: -49.42368799448013
#
# Average sentence log-prob: -52.25352312158793
# -52.25352312158793

# %%
get_sentence_prob("This is a sentence.")
get_sentence_prob("This is a macrame.", verbose=False)
get_sentence_prob("This is a joke.", verbose=False)
get_sentence_prob("Are you kidding me?", verbose=False)
# Out:
# Processing sentence: ['[CLS]', 'this', 'is', 'a', 'sentence', '.', '[SEP]']
#
# Word: this 	 Prob_forward: -8.96243667602539; Prob_backwards: -2.806614875793457
# Word: is 	 Prob_forward: -0.9202368259429932; Prob_backwards: -2.717599630355835
# Word: a 	 Prob_forward: -2.6885783672332764; Prob_backwards: -1.4664157629013062
# Word: sentence 	 Prob_forward: -8.932842254638672; Prob_backwards: -13.830182075500488
# Word: . 	 Prob_forward: -0.034496162086725235; Prob_backwards: -0.2193736732006073
# Raw forward sentence probability: -21.538590285927057
# Raw backward sentence probability: -21.040186017751694
#
# Average sentence log-prob: -21.289388151839375
#
# Processing sentence: ['[CLS]', 'this', 'is', 'a', 'mac', '##ram', '##e', '.', '[SEP]']
#
# Word: this 	 Prob_forward: -8.641555786132812; Prob_backwards: -2.8921501636505127
# Word: is 	 Prob_forward: -2.040065050125122; Prob_backwards: -2.0970122814178467
# Word: a 	 Prob_forward: -0.29191794991493225; Prob_backwards: -3.2476935386657715
# Word: mac 	 Prob_forward: -10.263047218322754; Prob_backwards: -3.448622941970825
# Word: ##ram 	 Prob_forward: -10.305248260498047; Prob_backwards: -7.932315826416016
# Word: ##e 	 Prob_forward: -0.0005695653380826116; Prob_backwards: -6.46556282043457
# Word: . 	 Prob_forward: -0.03617343306541443; Prob_backwards: -0.3660288155078888
# Raw forward sentence probability: -31.578577263397165
# Raw backward sentence probability: -26.44938638806343
#
# Average sentence log-prob: -29.013981825730298
#
# Processing sentence: ['[CLS]', 'this', 'is', 'a', 'joke', '.', '[SEP]']
#
# Word: this 	 Prob_forward: -8.96243667602539; Prob_backwards: -0.05858234688639641
# Word: is 	 Prob_forward: -0.9202368259429932; Prob_backwards: -4.270059108734131
# Word: a 	 Prob_forward: -2.6885783672332764; Prob_backwards: -0.12290707975625992
# Word: joke 	 Prob_forward: -3.717236280441284; Prob_backwards: -13.15233039855957
# Word: . 	 Prob_forward: -0.015418469905853271; Prob_backwards: -0.2193736732006073
# Raw forward sentence probability: -16.303906619548798
# Raw backward sentence probability: -17.823252607136965
#
# Average sentence log-prob: -17.06357961334288
#
# Processing sentence: ['[CLS]', 'are', 'you', 'kidding', 'me', '?', '[SEP]']
#
# Word: are 	 Prob_forward: -10.964299201965332; Prob_backwards: -5.030758256907575e-05
# Word: you 	 Prob_forward: -1.5613949298858643; Prob_backwards: -0.24156653881072998
# Word: kidding 	 Prob_forward: -4.023233413696289; Prob_backwards: -5.827249050140381
# Word: me 	 Prob_forward: -0.00013197340012993664; Prob_backwards: -6.045007705688477
# Word: ? 	 Prob_forward: -2.443820449116174e-05; Prob_backwards: -5.7042646408081055
# Raw forward sentence probability: -16.549083957152106
# Raw backward sentence probability: -17.818138243030262
#
# Average sentence log-prob: -17.183611100091184
# -17.183611100091184

# %%
get_sentence_prob("Rachel was wearing a lovely satin dress last night.")
# Out:
# Processing sentence: ['[CLS]', 'rachel', 'was', 'wearing', 'a', 'lovely', 'satin', 'dress', 'last', 'night', '.', '[SEP]']
#
# Word: rachel 	 Prob_forward: -11.216014862060547; Prob_backwards: -7.034425258636475
# Word: was 	 Prob_forward: -1.3298773765563965; Prob_backwards: -0.0013975725742056966
# Word: wearing 	 Prob_forward: -10.184678077697754; Prob_backwards: -2.1435110569000244
# Word: a 	 Prob_forward: -0.09067000448703766; Prob_backwards: -0.10912982374429703
# Word: lovely 	 Prob_forward: -7.708806037902832; Prob_backwards: -9.332859992980957
# Word: satin 	 Prob_forward: -6.861915588378906; Prob_backwards: -10.842044830322266
# Word: dress 	 Prob_forward: -3.8740289211273193; Prob_backwards: -13.085378646850586
# Word: last 	 Prob_forward: -5.801358699798584; Prob_backwards: -2.8171958923339844
# Word: night 	 Prob_forward: -0.052345097064971924; Prob_backwards: -8.598824501037598
# Word: . 	 Prob_forward: -0.010135823860764503; Prob_backwards: -0.20058058202266693
# Raw forward sentence probability: -47.12983048893511
# Raw backward sentence probability: -54.16534815740306
#
# Average sentence log-prob: -50.647589323169086
# -50.647589323169086

# %%
get_sentence_prob("Rachel was wearing a lovely satin dress last night.")
get_sentence_prob("Grandma was wearing a lovely satin dress last night.")
get_sentence_prob("Mother was wearing a lovely satin dress last night.")
get_sentence_prob("She was wearing a lovely satin dress last night.")
get_sentence_prob("He was wearing a lovely satin dress last night.")
get_sentence_prob("I was wearing a lovely satin dress last night.")
get_sentence_prob("Angela was wearing a lovely satin dress last night.")
get_sentence_prob("Roberta was wearing a lovely satin dress last night.")
get_sentence_prob("Running was wearing a lovely satin dress last night.")
# Out:
# Processing sentence: ['[CLS]', 'rachel', 'was', 'wearing', 'a', 'lovely', 'satin', 'dress', 'last', 'night', '.', '[SEP]']
#
# Word: rachel 	 Prob_forward: -11.216014862060547; Prob_backwards: -7.034425258636475
# Word: was 	 Prob_forward: -1.3298773765563965; Prob_backwards: -0.0013975725742056966
# Word: wearing 	 Prob_forward: -10.184678077697754; Prob_backwards: -2.1435110569000244
# Word: a 	 Prob_forward: -0.09067000448703766; Prob_backwards: -0.10912982374429703
# Word: lovely 	 Prob_forward: -7.708806037902832; Prob_backwards: -9.332859992980957
# Word: satin 	 Prob_forward: -6.861915588378906; Prob_backwards: -10.842044830322266
# Word: dress 	 Prob_forward: -3.8740289211273193; Prob_backwards: -13.085378646850586
# Word: last 	 Prob_forward: -5.801358699798584; Prob_backwards: -2.8171958923339844
# Word: night 	 Prob_forward: -0.052345097064971924; Prob_backwards: -8.598824501037598
# Word: . 	 Prob_forward: -0.010135823860764503; Prob_backwards: -0.20058058202266693
# Raw forward sentence probability: -47.12983048893511
# Raw backward sentence probability: -54.16534815740306
#
# Average sentence log-prob: -50.647589323169086
#
# Processing sentence: ['[CLS]', 'grandma', 'was', 'wearing', 'a', 'lovely', 'satin', 'dress', 'last', 'night', '.', '[SEP]']
#
# Word: grandma 	 Prob_forward: -12.527755737304688; Prob_backwards: -8.964543342590332
# Word: was 	 Prob_forward: -5.978592395782471; Prob_backwards: -0.0013975725742056966
# Word: wearing 	 Prob_forward: -7.364663600921631; Prob_backwards: -2.1435110569000244
# Word: a 	 Prob_forward: -0.1066005676984787; Prob_backwards: -0.10912982374429703
# Word: lovely 	 Prob_forward: -6.373819351196289; Prob_backwards: -9.332859992980957
# Word: satin 	 Prob_forward: -6.919576644897461; Prob_backwards: -10.842044830322266
# Word: dress 	 Prob_forward: -4.037703990936279; Prob_backwards: -13.085378646850586
# Word: last 	 Prob_forward: -5.723130226135254; Prob_backwards: -2.8171958923339844
# Word: night 	 Prob_forward: -0.0931050032377243; Prob_backwards: -8.598824501037598
# Word: . 	 Prob_forward: -0.006246785167604685; Prob_backwards: -0.20058058202266693
# Raw forward sentence probability: -49.13119430327788
# Raw backward sentence probability: -56.09546624135692
#
# Average sentence log-prob: -52.6133302723174
#
# Processing sentence: ['[CLS]', 'mother', 'was', 'wearing', 'a', 'lovely', 'satin', 'dress', 'last', 'night', '.', '[SEP]']
#
# Word: mother 	 Prob_forward: -10.062114715576172; Prob_backwards: -7.599658012390137
# Word: was 	 Prob_forward: -4.844198226928711; Prob_backwards: -0.0013975725742056966
# Word: wearing 	 Prob_forward: -9.533343315124512; Prob_backwards: -2.1435110569000244
# Word: a 	 Prob_forward: -0.12867151200771332; Prob_backwards: -0.10912982374429703
# Word: lovely 	 Prob_forward: -7.13240909576416; Prob_backwards: -9.332859992980957
# Word: satin 	 Prob_forward: -6.3588385581970215; Prob_backwards: -10.842044830322266
# Word: dress 	 Prob_forward: -3.914062261581421; Prob_backwards: -13.085378646850586
# Word: last 	 Prob_forward: -6.67264986038208; Prob_backwards: -2.8171958923339844
# Word: night 	 Prob_forward: -0.04959927126765251; Prob_backwards: -8.598824501037598
# Word: . 	 Prob_forward: -0.01422466803342104; Prob_backwards: -0.20058058202266693
# Raw forward sentence probability: -48.710111484862864
# Raw backward sentence probability: -54.73058091115672
#
# Average sentence log-prob: -51.72034619800979
#
# Processing sentence: ['[CLS]', 'she', 'was', 'wearing', 'a', 'lovely', 'satin', 'dress', 'last', 'night', '.', '[SEP]']
#
# Word: she 	 Prob_forward: -8.44726848602295; Prob_backwards: -0.49484628438949585
# Word: was 	 Prob_forward: -0.10163749009370804; Prob_backwards: -0.0013975725742056966
# Word: wearing 	 Prob_forward: -8.598554611206055; Prob_backwards: -2.1435110569000244
# Word: a 	 Prob_forward: -0.06749188899993896; Prob_backwards: -0.10912982374429703
# Word: lovely 	 Prob_forward: -7.291183948516846; Prob_backwards: -9.332859992980957
# Word: satin 	 Prob_forward: -6.636594295501709; Prob_backwards: -10.842044830322266
# Word: dress 	 Prob_forward: -3.714202880859375; Prob_backwards: -13.085378646850586
# Word: last 	 Prob_forward: -6.415935516357422; Prob_backwards: -2.8171958923339844
# Word: night 	 Prob_forward: -0.03868648037314415; Prob_backwards: -8.598824501037598
# Word: . 	 Prob_forward: -0.009446574375033379; Prob_backwards: -0.20058058202266693
# Raw forward sentence probability: -41.32100217230618
# Raw backward sentence probability: -47.62576918315608
#
# Average sentence log-prob: -44.47338567773113
#
# Processing sentence: ['[CLS]', 'he', 'was', 'wearing', 'a', 'lovely', 'satin', 'dress', 'last', 'night', '.', '[SEP]']
#
# Word: he 	 Prob_forward: -8.046318054199219; Prob_backwards: -5.060084819793701
# Word: was 	 Prob_forward: -0.406611829996109; Prob_backwards: -0.0013975725742056966
# Word: wearing 	 Prob_forward: -8.758685111999512; Prob_backwards: -2.1435110569000244
# Word: a 	 Prob_forward: -0.07345989346504211; Prob_backwards: -0.10912982374429703
# Word: lovely 	 Prob_forward: -9.185357093811035; Prob_backwards: -9.332859992980957
# Word: satin 	 Prob_forward: -7.393074035644531; Prob_backwards: -10.842044830322266
# Word: dress 	 Prob_forward: -4.252472877502441; Prob_backwards: -13.085378646850586
# Word: last 	 Prob_forward: -6.457747936248779; Prob_backwards: -2.8171958923339844
# Word: night 	 Prob_forward: -0.037084657698869705; Prob_backwards: -8.598824501037598
# Word: . 	 Prob_forward: -0.015559941530227661; Prob_backwards: -0.20058058202266693
# Raw forward sentence probability: -44.626371432095766
# Raw backward sentence probability: -52.191007718560286
#
# Average sentence log-prob: -48.408689575328026
#
# Processing sentence: ['[CLS]', 'i', 'was', 'wearing', 'a', 'lovely', 'satin', 'dress', 'last', 'night', '.', '[SEP]']
#
# Word: i 	 Prob_forward: -7.4424567222595215; Prob_backwards: -1.2183178663253784
# Word: was 	 Prob_forward: -0.5767527222633362; Prob_backwards: -0.0013975725742056966
# Word: wearing 	 Prob_forward: -10.010024070739746; Prob_backwards: -2.1435110569000244
# Word: a 	 Prob_forward: -0.11708797514438629; Prob_backwards: -0.10912982374429703
# Word: lovely 	 Prob_forward: -7.308903694152832; Prob_backwards: -9.332859992980957
# Word: satin 	 Prob_forward: -6.993312835693359; Prob_backwards: -10.842044830322266
# Word: dress 	 Prob_forward: -3.851733922958374; Prob_backwards: -13.085378646850586
# Word: last 	 Prob_forward: -5.071983337402344; Prob_backwards: -2.8171958923339844
# Word: night 	 Prob_forward: -0.04053365811705589; Prob_backwards: -8.598824501037598
# Word: . 	 Prob_forward: -0.010847540572285652; Prob_backwards: -0.20058058202266693
# Raw forward sentence probability: -41.42363647930324
# Raw backward sentence probability: -48.34924076509196
#
# Average sentence log-prob: -44.8864386221976
#
# Processing sentence: ['[CLS]', 'angela', 'was', 'wearing', 'a', 'lovely', 'satin', 'dress', 'last', 'night', '.', '[SEP]']
#
# Word: angela 	 Prob_forward: -11.655869483947754; Prob_backwards: -10.419659614562988
# Word: was 	 Prob_forward: -7.0399274826049805; Prob_backwards: -0.0013975725742056966
# Word: wearing 	 Prob_forward: -9.589070320129395; Prob_backwards: -2.1435110569000244
# Word: a 	 Prob_forward: -0.0837114080786705; Prob_backwards: -0.10912982374429703
# Word: lovely 	 Prob_forward: -7.821934223175049; Prob_backwards: -9.332859992980957
# Word: satin 	 Prob_forward: -6.491084098815918; Prob_backwards: -10.842044830322266
# Word: dress 	 Prob_forward: -4.1755828857421875; Prob_backwards: -13.085378646850586
# Word: last 	 Prob_forward: -5.982906341552734; Prob_backwards: -2.8171958923339844
# Word: night 	 Prob_forward: -0.053289733827114105; Prob_backwards: -8.598824501037598
# Word: . 	 Prob_forward: -0.017475666478276253; Prob_backwards: -0.20058058202266693
# Raw forward sentence probability: -52.91085164435208
# Raw backward sentence probability: -57.55058251332957
#
# Average sentence log-prob: -55.230717078840826
#
# Processing sentence: ['[CLS]', 'roberta', 'was', 'wearing', 'a', 'lovely', 'satin', 'dress', 'last', 'night', '.', '[SEP]']
#
# Word: roberta 	 Prob_forward: -12.462820053100586; Prob_backwards: -11.279317855834961
# Word: was 	 Prob_forward: -7.545024394989014; Prob_backwards: -0.0013975725742056966
# Word: wearing 	 Prob_forward: -8.398049354553223; Prob_backwards: -2.1435110569000244
# Word: a 	 Prob_forward: -0.13754932582378387; Prob_backwards: -0.10912982374429703
# Word: lovely 	 Prob_forward: -7.054993152618408; Prob_backwards: -9.332859992980957
# Word: satin 	 Prob_forward: -6.726216793060303; Prob_backwards: -10.842044830322266
# Word: dress 	 Prob_forward: -3.9633948802948; Prob_backwards: -13.085378646850586
# Word: last 	 Prob_forward: -5.882959365844727; Prob_backwards: -2.8171958923339844
# Word: night 	 Prob_forward: -0.05768701061606407; Prob_backwards: -8.598824501037598
# Word: . 	 Prob_forward: -0.013864764012396336; Prob_backwards: -0.20058058202266693
# Raw forward sentence probability: -52.242559094913304
# Raw backward sentence probability: -58.410240754601546
#
# Average sentence log-prob: -55.326399924757425
#
# Processing sentence: ['[CLS]', 'running', 'was', 'wearing', 'a', 'lovely', 'satin', 'dress', 'last', 'night', '.', '[SEP]']
#
# Word: running 	 Prob_forward: -11.862516403198242; Prob_backwards: -14.420729637145996
# Word: was 	 Prob_forward: -7.9794464111328125; Prob_backwards: -0.0013975725742056966
# Word: wearing 	 Prob_forward: -11.666500091552734; Prob_backwards: -2.1435110569000244
# Word: a 	 Prob_forward: -0.3484455645084381; Prob_backwards: -0.10912982374429703
# Word: lovely 	 Prob_forward: -8.561259269714355; Prob_backwards: -9.332859992980957
# Word: satin 	 Prob_forward: -7.116202354431152; Prob_backwards: -10.842044830322266
# Word: dress 	 Prob_forward: -4.106448173522949; Prob_backwards: -13.085378646850586
# Word: last 	 Prob_forward: -6.536173343658447; Prob_backwards: -2.8171958923339844
# Word: night 	 Prob_forward: -0.04523945972323418; Prob_backwards: -8.598824501037598
# Word: . 	 Prob_forward: -0.012135349214076996; Prob_backwards: -0.20058058202266693
# Raw forward sentence probability: -58.23436642065644
# Raw backward sentence probability: -61.55165253591258
#
# Average sentence log-prob: -59.89300947828451
# -59.89300947828451

# %%
get_sentence_prob("The man ate the steak.")
get_sentence_prob("The stake ate the man.")
get_sentence_prob("The man who arrived late ate the steak with a glass of wine.")
get_sentence_prob("The steak was eaten by the man.")
get_sentence_prob("The man was eaten by the stake.")
# Out:
# Processing sentence: ['[CLS]', 'the', 'man', 'ate', 'the', 'steak', '.', '[SEP]']
#
# Word: the 	 Prob_forward: -5.038585662841797; Prob_backwards: -0.05858740955591202
# Word: man 	 Prob_forward: -7.065206050872803; Prob_backwards: -9.936883926391602
# Word: ate 	 Prob_forward: -8.079832077026367; Prob_backwards: -4.224849700927734
# Word: the 	 Prob_forward: -1.8303484916687012; Prob_backwards: -3.6972944736480713
# Word: steak 	 Prob_forward: -5.370851039886475; Prob_backwards: -11.686675071716309
# Word: . 	 Prob_forward: -0.005581368692219257; Prob_backwards: -0.3288889527320862
# Raw forward sentence probability: -27.390404690988362
# Raw backward sentence probability: -29.933179534971714
#
# Average sentence log-prob: -28.661792112980038
#
# Processing sentence: ['[CLS]', 'the', 'stake', 'ate', 'the', 'man', '.', '[SEP]']
#
# Word: the 	 Prob_forward: -5.038585662841797; Prob_backwards: -0.1620464026927948
# Word: stake 	 Prob_forward: -9.997936248779297; Prob_backwards: -9.75770378112793
# Word: ate 	 Prob_forward: -13.749679565429688; Prob_backwards: -11.545761108398438
# Word: the 	 Prob_forward: -2.346017837524414; Prob_backwards: -2.7685909271240234
# Word: man 	 Prob_forward: -6.172815799713135; Prob_backwards: -8.939630508422852
# Word: . 	 Prob_forward: -0.0013029716210439801; Prob_backwards: -0.3288889527320862
# Raw forward sentence probability: -37.306338085909374
# Raw backward sentence probability: -33.50262168049812
#
# Average sentence log-prob: -35.40447988320375
#
# Processing sentence: ['[CLS]', 'the', 'man', 'who', 'arrived', 'late', 'ate', 'the', 'steak', 'with', 'a', 'glass', 'of', 'wine', '.', '[SEP]']
#
# Word: the 	 Prob_forward: -2.4361023902893066; Prob_backwards: -0.06899606436491013
# Word: man 	 Prob_forward: -9.16815185546875; Prob_backwards: -3.4415459632873535
# Word: who 	 Prob_forward: -1.2240636348724365; Prob_backwards: -0.6637316942214966
# Word: arrived 	 Prob_forward: -11.06530475616455; Prob_backwards: -6.861131191253662
# Word: late 	 Prob_forward: -6.512383460998535; Prob_backwards: -12.389859199523926
# Word: ate 	 Prob_forward: -10.573854446411133; Prob_backwards: -5.250829219818115
# Word: the 	 Prob_forward: -3.1412062644958496; Prob_backwards: -1.6597065925598145
# Word: steak 	 Prob_forward: -4.342452526092529; Prob_backwards: -11.699100494384766
# Word: with 	 Prob_forward: -0.8466789722442627; Prob_backwards: -2.9649083614349365
# Word: a 	 Prob_forward: -0.23903727531433105; Prob_backwards: -0.08892388641834259
# Word: glass 	 Prob_forward: -8.718300819396973; Prob_backwards: -3.2289481163024902
# Word: of 	 Prob_forward: -0.004949340596795082; Prob_backwards: -5.452270984649658
# Word: wine 	 Prob_forward: -0.47417157888412476; Prob_backwards: -11.46838665008545
# Word: . 	 Prob_forward: -0.008378580212593079; Prob_backwards: -0.2731572985649109
# Raw forward sentence probability: -58.75503590144217
# Raw backward sentence probability: -65.51149571686983
#
# Average sentence log-prob: -62.133265809156
#
# Processing sentence: ['[CLS]', 'the', 'steak', 'was', 'eaten', 'by', 'the', 'man', '.', '[SEP]']
#
# Word: the 	 Prob_forward: -5.768765449523926; Prob_backwards: -0.2115747332572937
# Word: steak 	 Prob_forward: -11.673186302185059; Prob_backwards: -7.993943691253662
# Word: was 	 Prob_forward: -2.6474661827087402; Prob_backwards: -0.3107675015926361
# Word: eaten 	 Prob_forward: -8.51375675201416; Prob_backwards: -6.463120460510254
# Word: by 	 Prob_forward: -2.290250539779663; Prob_backwards: -6.271388530731201
# Word: the 	 Prob_forward: -0.592404842376709; Prob_backwards: -3.712545156478882
# Word: man 	 Prob_forward: -5.889617443084717; Prob_backwards: -7.768515110015869
# Word: . 	 Prob_forward: -0.024163832888007164; Prob_backwards: -0.3001890182495117
# Raw forward sentence probability: -37.39961134456098
# Raw backward sentence probability: -33.03204420208931
#
# Average sentence log-prob: -35.215827773325145
#
# Processing sentence: ['[CLS]', 'the', 'man', 'was', 'eaten', 'by', 'the', 'stake', '.', '[SEP]']
#
# Word: the 	 Prob_forward: -5.768765449523926; Prob_backwards: -1.0661392211914062
# Word: man 	 Prob_forward: -4.031982898712158; Prob_backwards: -4.405887126922607
# Word: was 	 Prob_forward: -0.36513328552246094; Prob_backwards: -0.6598386168479919
# Word: eaten 	 Prob_forward: -13.154004096984863; Prob_backwards: -5.658388137817383
# Word: by 	 Prob_forward: -0.9767062664031982; Prob_backwards: -8.883917808532715
# Word: the 	 Prob_forward: -0.7629978060722351; Prob_backwards: -8.572261810302734
# Word: stake 	 Prob_forward: -9.989922523498535; Prob_backwards: -12.414676666259766
# Word: . 	 Prob_forward: -0.03000684082508087; Prob_backwards: -0.3001890182495117
# Raw forward sentence probability: -35.07951916754246
# Raw backward sentence probability: -41.961298406124115
#
# Average sentence log-prob: -38.520408786833286
# -38.520408786833286

# %%
get_sentence_prob("He was born in Berlin.")
get_sentence_prob("He was born in Santiago.")
get_sentence_prob("He was born in France.")
get_sentence_prob("He was born in window.")
get_sentence_prob("He was born in was.")
# Out:
# Processing sentence: ['[CLS]', 'he', 'was', 'born', 'in', 'berlin', '.', '[SEP]']
#
# Word: he 	 Prob_forward: -7.282431602478027; Prob_backwards: -0.2271691858768463
# Word: was 	 Prob_forward: -0.49251610040664673; Prob_backwards: -7.152582838898525e-06
# Word: born 	 Prob_forward: -9.202768325805664; Prob_backwards: -7.146602153778076
# Word: in 	 Prob_forward: -0.004424570593982935; Prob_backwards: -2.567709445953369
# Word: berlin 	 Prob_forward: -3.735508441925049; Prob_backwards: -9.517555236816406
# Word: . 	 Prob_forward: -6.52096132398583e-05; Prob_backwards: -0.3288889527320862
# Raw forward sentence probability: -20.71771425082261
# Raw backward sentence probability: -19.787932127739623
#
# Average sentence log-prob: -20.252823189281116
#
# Processing sentence: ['[CLS]', 'he', 'was', 'born', 'in', 'santiago', '.', '[SEP]']
#
# Word: he 	 Prob_forward: -7.282431602478027; Prob_backwards: -0.27283912897109985
# Word: was 	 Prob_forward: -0.49251610040664673; Prob_backwards: -7.999262743396685e-05
# Word: born 	 Prob_forward: -9.202768325805664; Prob_backwards: -5.878465175628662
# Word: in 	 Prob_forward: -0.004424570593982935; Prob_backwards: -5.8249101638793945
# Word: santiago 	 Prob_forward: -6.795576095581055; Prob_backwards: -11.235332489013672
# Word: . 	 Prob_forward: -0.00011742804053938016; Prob_backwards: -0.3288889527320862
# Raw forward sentence probability: -23.777834122905915
# Raw backward sentence probability: -23.54051590285235
#
# Average sentence log-prob: -23.659175012879132
#
# Processing sentence: ['[CLS]', 'he', 'was', 'born', 'in', 'france', '.', '[SEP]']
#
# Word: he 	 Prob_forward: -7.282431602478027; Prob_backwards: -0.2318655550479889
# Word: was 	 Prob_forward: -0.49251610040664673; Prob_backwards: -5.054601570009254e-05
# Word: born 	 Prob_forward: -9.202768325805664; Prob_backwards: -3.3717470169067383
# Word: in 	 Prob_forward: -0.004424570593982935; Prob_backwards: -1.6186631917953491
# Word: france 	 Prob_forward: -6.048434734344482; Prob_backwards: -10.258139610290527
# Word: . 	 Prob_forward: -0.0002082206920022145; Prob_backwards: -0.3288889527320862
# Raw forward sentence probability: -23.030783554320806
# Raw backward sentence probability: -15.80935487278839
#
# Average sentence log-prob: -19.420069213554598
#
# Processing sentence: ['[CLS]', 'he', 'was', 'born', 'in', 'window', '.', '[SEP]']
#
# Word: he 	 Prob_forward: -7.282431602478027; Prob_backwards: -0.42410939931869507
# Word: was 	 Prob_forward: -0.49251610040664673; Prob_backwards: -0.0005181581364013255
# Word: born 	 Prob_forward: -9.202768325805664; Prob_backwards: -10.539138793945312
# Word: in 	 Prob_forward: -0.004424570593982935; Prob_backwards: -4.716119289398193
# Word: window 	 Prob_forward: -13.621142387390137; Prob_backwards: -9.957900047302246
# Word: . 	 Prob_forward: -0.008476918563246727; Prob_backwards: -0.3288889527320862
# Raw forward sentence probability: -30.611759905237705
# Raw backward sentence probability: -25.966674640832935
#
# Average sentence log-prob: -28.28921727303532
#
# Processing sentence: ['[CLS]', 'he', 'was', 'born', 'in', 'was', '.', '[SEP]']
#
# Word: he 	 Prob_forward: -7.282431602478027; Prob_backwards: -0.33688920736312866
# Word: was 	 Prob_forward: -0.49251610040664673; Prob_backwards: -0.00014914195344317704
# Word: born 	 Prob_forward: -9.202768325805664; Prob_backwards: -8.491011619567871
# Word: in 	 Prob_forward: -0.004424570593982935; Prob_backwards: -9.724106788635254
# Word: was 	 Prob_forward: -13.725293159484863; Prob_backwards: -9.836736679077148
# Word: . 	 Prob_forward: -0.005059982184320688; Prob_backwards: -0.3288889527320862
# Raw forward sentence probability: -30.712493740953505
# Raw backward sentence probability: -28.71778238932893
#
# Average sentence log-prob: -29.71513806514122
# -29.71513806514122

# %%
get_sentence_prob("I fed my cat some of it and he damn near passed out.")
get_sentence_prob("I fed my dog some of it and he damn near passed out.")
get_sentence_prob("I fed my window some of it and he damn near passed out.")
get_sentence_prob("I fed my the some of it and he damn near passed out.")
# Out:
# Processing sentence: ['[CLS]', 'i', 'fed', 'my', 'cat', 'some', 'of', 'it', 'and', 'he', 'damn', 'near', 'passed', 'out', '.', '[SEP]']
#
# Word: i 	 Prob_forward: -7.554384708404541; Prob_backwards: -0.004160344135016203
# Word: fed 	 Prob_forward: -10.962949752807617; Prob_backwards: -1.7643972635269165
# Word: my 	 Prob_forward: -4.395064830780029; Prob_backwards: -2.2217588424682617
# Word: cat 	 Prob_forward: -6.011991500854492; Prob_backwards: -13.184957504272461
# Word: some 	 Prob_forward: -4.910660743713379; Prob_backwards: -5.519116401672363
# Word: of 	 Prob_forward: -10.968462944030762; Prob_backwards: -2.6849160194396973
# Word: it 	 Prob_forward: -8.965747833251953; Prob_backwards: -10.607772827148438
# Word: and 	 Prob_forward: -0.6076505184173584; Prob_backwards: -0.6773967742919922
# Word: he 	 Prob_forward: -5.089953422546387; Prob_backwards: -3.030817985534668
# Word: damn 	 Prob_forward: -10.677398681640625; Prob_backwards: -0.3554331958293915
# Word: near 	 Prob_forward: -0.8748708367347717; Prob_backwards: -9.197769165039062
# Word: passed 	 Prob_forward: -9.488633155822754; Prob_backwards: -6.476246356964111
# Word: out 	 Prob_forward: -0.0005055752117186785; Prob_backwards: -8.81843376159668
# Word: . 	 Prob_forward: -0.000843880872707814; Prob_backwards: -0.2731572985649109
# Raw forward sentence probability: -80.5091183850891
# Raw backward sentence probability: -64.81633374048397
#
# Average sentence log-prob: -72.66272606278653
#
# Processing sentence: ['[CLS]', 'i', 'fed', 'my', 'dog', 'some', 'of', 'it', 'and', 'he', 'damn', 'near', 'passed', 'out', '.', '[SEP]']
#
# Word: i 	 Prob_forward: -7.554384708404541; Prob_backwards: -0.0030807575676590204
# Word: fed 	 Prob_forward: -10.962949752807617; Prob_backwards: -1.8176600933074951
# Word: my 	 Prob_forward: -4.395064830780029; Prob_backwards: -1.36171555519104
# Word: dog 	 Prob_forward: -6.2797980308532715; Prob_backwards: -10.893427848815918
# Word: some 	 Prob_forward: -3.7220940589904785; Prob_backwards: -5.519116401672363
# Word: of 	 Prob_forward: -9.575020790100098; Prob_backwards: -2.6849160194396973
# Word: it 	 Prob_forward: -8.620244026184082; Prob_backwards: -10.607772827148438
# Word: and 	 Prob_forward: -0.5948904752731323; Prob_backwards: -0.6773967742919922
# Word: he 	 Prob_forward: -6.234775066375732; Prob_backwards: -3.030817985534668
# Word: damn 	 Prob_forward: -10.455896377563477; Prob_backwards: -0.3554331958293915
# Word: near 	 Prob_forward: -0.8546912670135498; Prob_backwards: -9.197769165039062
# Word: passed 	 Prob_forward: -9.391928672790527; Prob_backwards: -6.476246356964111
# Word: out 	 Prob_forward: -0.0005506004672497511; Prob_backwards: -8.81843376159668
# Word: . 	 Prob_forward: -0.0013818747829645872; Prob_backwards: -0.2731572985649109
# Raw forward sentence probability: -78.64367053238675
# Raw backward sentence probability: -61.716944040963426
#
# Average sentence log-prob: -70.18030728667509
#
# Processing sentence: ['[CLS]', 'i', 'fed', 'my', 'window', 'some', 'of', 'it', 'and', 'he', 'damn', 'near', 'passed', 'out', '.', '[SEP]']
#
# Word: i 	 Prob_forward: -7.554384708404541; Prob_backwards: -0.033292319625616074
# Word: fed 	 Prob_forward: -10.962949752807617; Prob_backwards: -9.02365493774414
# Word: my 	 Prob_forward: -4.395064830780029; Prob_backwards: -2.896864414215088
# Word: window 	 Prob_forward: -10.389808654785156; Prob_backwards: -12.297268867492676
# Word: some 	 Prob_forward: -9.806970596313477; Prob_backwards: -5.519116401672363
# Word: of 	 Prob_forward: -8.150537490844727; Prob_backwards: -2.6849160194396973
# Word: it 	 Prob_forward: -8.104621887207031; Prob_backwards: -10.607772827148438
# Word: and 	 Prob_forward: -0.9268238544464111; Prob_backwards: -0.6773967742919922
# Word: he 	 Prob_forward: -9.741223335266113; Prob_backwards: -3.030817985534668
# Word: damn 	 Prob_forward: -11.525473594665527; Prob_backwards: -0.3554331958293915
# Word: near 	 Prob_forward: -1.4332841634750366; Prob_backwards: -9.197769165039062
# Word: passed 	 Prob_forward: -8.937289237976074; Prob_backwards: -6.476246356964111
# Word: out 	 Prob_forward: -0.0006731629255227745; Prob_backwards: -8.81843376159668
# Word: . 	 Prob_forward: -0.0005730840493924916; Prob_backwards: -0.2731572985649109
# Raw forward sentence probability: -91.92967835394666
# Raw backward sentence probability: -71.89214032515883
#
# Average sentence log-prob: -81.91090933955275
#
# Processing sentence: ['[CLS]', 'i', 'fed', 'my', 'the', 'some', 'of', 'it', 'and', 'he', 'damn', 'near', 'passed', 'out', '.', '[SEP]']
#
# Word: i 	 Prob_forward: -7.554384708404541; Prob_backwards: -0.147112637758255
# Word: fed 	 Prob_forward: -10.962949752807617; Prob_backwards: -5.445777893066406
# Word: my 	 Prob_forward: -4.395064830780029; Prob_backwards: -9.644237518310547
# Word: the 	 Prob_forward: -7.5686492919921875; Prob_backwards: -8.506264686584473
# Word: some 	 Prob_forward: -10.30285358428955; Prob_backwards: -5.519116401672363
# Word: of 	 Prob_forward: -4.059378623962402; Prob_backwards: -2.6849160194396973
# Word: it 	 Prob_forward: -5.6377058029174805; Prob_backwards: -10.607772827148438
# Word: and 	 Prob_forward: -0.8954987525939941; Prob_backwards: -0.6773967742919922
# Word: he 	 Prob_forward: -7.935787677764893; Prob_backwards: -3.030817985534668
# Word: damn 	 Prob_forward: -13.064457893371582; Prob_backwards: -0.3554331958293915
# Word: near 	 Prob_forward: -1.5153154134750366; Prob_backwards: -9.197769165039062
# Word: passed 	 Prob_forward: -8.556652069091797; Prob_backwards: -6.476246356964111
# Word: out 	 Prob_forward: -0.00029109182651154697; Prob_backwards: -8.81843376159668
# Word: . 	 Prob_forward: -0.0013766223564743996; Prob_backwards: -0.2731572985649109
# Raw forward sentence probability: -82.4503661156341
# Raw backward sentence probability: -71.384452521801
#
# Average sentence log-prob: -76.91740931871755
# -76.91740931871755

# %%
print("Should have similar/high probs\n")
get_sentence_prob("I forgot to take my medicine.")
get_sentence_prob("I forgot to take my medicines.")
get_sentence_prob("I forgot to take my medication.")
get_sentence_prob("I forgot to take my pills.")
get_sentence_prob("I forgot to take my turn.")
print("Should have low probs\n")
get_sentence_prob("I forgot to take my medical.")
get_sentence_prob("I forgot to take my medically.")
get_sentence_prob("I forgot to take my turned.")
# Out:
# Should have similar/high probs
#
# Processing sentence: ['[CLS]', 'i', 'forgot', 'to', 'take', 'my', 'medicine', '.', '[SEP]']
#
# Word: i 	 Prob_forward: -6.841585636138916; Prob_backwards: -0.009423289448022842
# Word: forgot 	 Prob_forward: -8.716732025146484; Prob_backwards: -4.86270809173584
# Word: to 	 Prob_forward: -2.7058005332946777; Prob_backwards: -0.22967574000358582
# Word: take 	 Prob_forward: -2.5964887142181396; Prob_backwards: -4.419327735900879
# Word: my 	 Prob_forward: -1.2803349494934082; Prob_backwards: -10.081429481506348
# Word: medicine 	 Prob_forward: -4.346566677093506; Prob_backwards: -10.121175765991211
# Word: . 	 Prob_forward: -0.002095509320497513; Prob_backwards: -0.3660288155078888
# Raw forward sentence probability: -26.48960404470563
# Raw backward sentence probability: -30.089768920093775
#
# Average sentence log-prob: -28.289686482399702
#
# Processing sentence: ['[CLS]', 'i', 'forgot', 'to', 'take', 'my', 'medicines', '.', '[SEP]']
#
# Word: i 	 Prob_forward: -6.841585636138916; Prob_backwards: -0.023220982402563095
# Word: forgot 	 Prob_forward: -8.716732025146484; Prob_backwards: -3.822361707687378
# Word: to 	 Prob_forward: -2.7058005332946777; Prob_backwards: -0.7924853563308716
# Word: take 	 Prob_forward: -2.5964887142181396; Prob_backwards: -6.266132831573486
# Word: my 	 Prob_forward: -1.2803349494934082; Prob_backwards: -8.426331520080566
# Word: medicines 	 Prob_forward: -7.426791667938232; Prob_backwards: -12.554646492004395
# Word: . 	 Prob_forward: -0.010277090594172478; Prob_backwards: -0.3660288155078888
# Raw forward sentence probability: -29.57801061682403
# Raw backward sentence probability: -32.25120770558715
#
# Average sentence log-prob: -30.91460916120559
#
# Processing sentence: ['[CLS]', 'i', 'forgot', 'to', 'take', 'my', 'medication', '.', '[SEP]']
#
# Word: i 	 Prob_forward: -6.841585636138916; Prob_backwards: -0.0019433893030509353
# Word: forgot 	 Prob_forward: -8.716732025146484; Prob_backwards: -3.83487606048584
# Word: to 	 Prob_forward: -2.7058005332946777; Prob_backwards: -0.17410892248153687
# Word: take 	 Prob_forward: -2.5964887142181396; Prob_backwards: -5.513833045959473
# Word: my 	 Prob_forward: -1.2803349494934082; Prob_backwards: -6.66896390914917
# Word: medication 	 Prob_forward: -2.9694972038269043; Prob_backwards: -13.070683479309082
# Word: . 	 Prob_forward: -0.0010937469778582454; Prob_backwards: -0.3660288155078888
# Raw forward sentence probability: -25.11153280909639
# Raw backward sentence probability: -29.63043762219604
#
# Average sentence log-prob: -27.370985215646215
#
# Processing sentence: ['[CLS]', 'i', 'forgot', 'to', 'take', 'my', 'pills', '.', '[SEP]']
#
# Word: i 	 Prob_forward: -6.841585636138916; Prob_backwards: -0.002008546842262149
# Word: forgot 	 Prob_forward: -8.716732025146484; Prob_backwards: -3.457310676574707
# Word: to 	 Prob_forward: -2.7058005332946777; Prob_backwards: -0.17102351784706116
# Word: take 	 Prob_forward: -2.5964887142181396; Prob_backwards: -4.905041217803955
# Word: my 	 Prob_forward: -1.2803349494934082; Prob_backwards: -6.40346622467041
# Word: pills 	 Prob_forward: -2.8659815788269043; Prob_backwards: -10.711495399475098
# Word: . 	 Prob_forward: -0.00189507647883147; Prob_backwards: -0.3660288155078888
# Raw forward sentence probability: -25.00881851359736
# Raw backward sentence probability: -26.016374398721382
#
# Average sentence log-prob: -25.512596456159372
#
# Processing sentence: ['[CLS]', 'i', 'forgot', 'to', 'take', 'my', 'turn', '.', '[SEP]']
#
# Word: i 	 Prob_forward: -6.841585636138916; Prob_backwards: -0.032163601368665695
# Word: forgot 	 Prob_forward: -8.716732025146484; Prob_backwards: -7.866517543792725
# Word: to 	 Prob_forward: -2.7058005332946777; Prob_backwards: -0.268136590719223
# Word: take 	 Prob_forward: -2.5964887142181396; Prob_backwards: -5.429475784301758
# Word: my 	 Prob_forward: -1.2803349494934082; Prob_backwards: -1.3207606077194214
# Word: turn 	 Prob_forward: -6.57351016998291; Prob_backwards: -12.252937316894531
# Word: . 	 Prob_forward: -0.004275927320122719; Prob_backwards: -0.3660288155078888
# Raw forward sentence probability: -28.71872795559466
# Raw backward sentence probability: -27.536020260304213
#
# Average sentence log-prob: -28.127374107949436
#
# Should have low probs
#
# Processing sentence: ['[CLS]', 'i', 'forgot', 'to', 'take', 'my', 'medical', '.', '[SEP]']
#
# Word: i 	 Prob_forward: -6.841585636138916; Prob_backwards: -0.07221221923828125
# Word: forgot 	 Prob_forward: -8.716732025146484; Prob_backwards: -5.4121503829956055
# Word: to 	 Prob_forward: -2.7058005332946777; Prob_backwards: -0.363259881734848
# Word: take 	 Prob_forward: -2.5964887142181396; Prob_backwards: -6.698975563049316
# Word: my 	 Prob_forward: -1.2803349494934082; Prob_backwards: -8.793343544006348
# Word: medical 	 Prob_forward: -11.388912200927734; Prob_backwards: -10.411707878112793
# Word: . 	 Prob_forward: -0.007230790797621012; Prob_backwards: -0.3660288155078888
# Raw forward sentence probability: -33.53708485001698
# Raw backward sentence probability: -32.11767828464508
#
# Average sentence log-prob: -32.82738156733103
#
# Processing sentence: ['[CLS]', 'i', 'forgot', 'to', 'take', 'my', 'medical', '##ly', '.', '[SEP]']
#
# Word: i 	 Prob_forward: -6.4704437255859375; Prob_backwards: -0.8298007845878601
# Word: forgot 	 Prob_forward: -9.972952842712402; Prob_backwards: -5.551814556121826
# Word: to 	 Prob_forward: -3.5935943126678467; Prob_backwards: -0.32450324296951294
# Word: take 	 Prob_forward: -2.4377553462982178; Prob_backwards: -6.535189628601074
# Word: my 	 Prob_forward: -1.4384831190109253; Prob_backwards: -11.799327850341797
# Word: medical 	 Prob_forward: -6.91756534576416; Prob_backwards: -10.492776870727539
# Word: ##ly 	 Prob_forward: -9.0018892288208; Prob_backwards: -6.816740036010742
# Word: . 	 Prob_forward: -0.017653705552220345; Prob_backwards: -0.3001890182495117
# Raw forward sentence probability: -39.85033762641251
# Raw backward sentence probability: -42.65034198760986
#
# Average sentence log-prob: -41.25033980701119
#
# Processing sentence: ['[CLS]', 'i', 'forgot', 'to', 'take', 'my', 'turned', '.', '[SEP]']
#
# Word: i 	 Prob_forward: -6.841585636138916; Prob_backwards: -0.03725879639387131
# Word: forgot 	 Prob_forward: -8.716732025146484; Prob_backwards: -7.182065963745117
# Word: to 	 Prob_forward: -2.7058005332946777; Prob_backwards: -0.034792717546224594
# Word: take 	 Prob_forward: -2.5964887142181396; Prob_backwards: -6.265805721282959
# Word: my 	 Prob_forward: -1.2803349494934082; Prob_backwards: -10.790841102600098
# Word: turned 	 Prob_forward: -12.86610221862793; Prob_backwards: -13.337825775146484
# Word: . 	 Prob_forward: -0.0025190822780132294; Prob_backwards: -0.3660288155078888
# Raw forward sentence probability: -35.00956315919757
# Raw backward sentence probability: -38.01461889222264
#
# Average sentence log-prob: -36.512091025710106
# -36.512091025710106

# %%
get_sentence_prob("We will explore the elements used to construct sentences, and what parts of speech are used to expand and elaborate on them.")
get_sentence_prob("Wikipedia is a multilingual online encyclopedia created and maintained as an open collaboration project by a community of volunteer editors.")
get_sentence_prob("Once she gave her a little cap of red velvet, which suited her so well that she would never wear anything else.")
# Out:
# Processing sentence: ['[CLS]', 'we', 'will', 'explore', 'the', 'elements', 'used', 'to', 'construct', 'sentences', ',', 'and', 'what', 'parts', 'of', 'speech', 'are', 'used', 'to', 'expand', 'and', 'elaborate', 'on', 'them', '.', '[SEP]']
#
# Word: we 	 Prob_forward: 0.0005438847583718598; Prob_backwards: 0.022272974252700806
# Word: will 	 Prob_forward: 0.008487698622047901; Prob_backwards: 0.024045974016189575
# Word: explore 	 Prob_forward: 9.5668867288623e-05; Prob_backwards: 0.0005457077058963478
# Word: the 	 Prob_forward: 0.1310628205537796; Prob_backwards: 0.08164729177951813
# Word: elements 	 Prob_forward: 1.3173785191611387e-05; Prob_backwards: 3.286916762590408e-05
# Word: used 	 Prob_forward: 1.640969276195392e-05; Prob_backwards: 0.9119576811790466
# Word: to 	 Prob_forward: 0.7283820509910583; Prob_backwards: 0.7407114505767822
# Word: construct 	 Prob_forward: 0.004861429799348116; Prob_backwards: 0.0010620743269100785
# Word: sentences 	 Prob_forward: 4.218660615151748e-05; Prob_backwards: 0.014396105892956257
# Word: , 	 Prob_forward: 0.7496650815010071; Prob_backwards: 0.16025103628635406
# Word: and 	 Prob_forward: 0.09914618730545044; Prob_backwards: 0.3078840970993042
# Word: what 	 Prob_forward: 0.0001570644963067025; Prob_backwards: 0.005911736283451319
# Word: parts 	 Prob_forward: 0.00020469058654271066; Prob_backwards: 0.14203208684921265
# Word: of 	 Prob_forward: 0.4028345048427582; Prob_backwards: 0.8784892559051514
# Word: speech 	 Prob_forward: 0.001155569450929761; Prob_backwards: 0.00017156453395728022
# Word: are 	 Prob_forward: 0.5121461749076843; Prob_backwards: 0.010490129701793194
# Word: used 	 Prob_forward: 0.032519977539777756; Prob_backwards: 0.0028340735007077456
# Word: to 	 Prob_forward: 0.9792649745941162; Prob_backwards: 0.8937673568725586
# Word: expand 	 Prob_forward: 0.00010410851973574609; Prob_backwards: 2.055747927443008e-06
# Word: and 	 Prob_forward: 0.13562537729740143; Prob_backwards: 0.004950935021042824
# Word: elaborate 	 Prob_forward: 0.0016422206535935402; Prob_backwards: 5.1207853175583296e-06
# Word: on 	 Prob_forward: 0.0009729608427733183; Prob_backwards: 0.01121716108173132
# Word: them 	 Prob_forward: 0.7933027148246765; Prob_backwards: 0.0002552553196437657
# Word: . 	 Prob_forward: 0.996337890625; Prob_backwards: 0.8380947709083557
# Geometric-mean forward sentence probability: 0.010716656282533838
# Geometric-mean backward sentence probability: 0.01330636996266248
#
# Average normalized sentence prob: 0.011941515534390365
#
# Processing sentence: ['[CLS]', 'wikipedia', 'is', 'a', 'multi', '##ling', '##ual', 'online', 'encyclopedia', 'created', 'and', 'maintained', 'as', 'an', 'open', 'collaboration', 'project', 'by', 'a', 'community', 'of', 'volunteer', 'editors', '.', '[SEP]']
#
# Word: wikipedia 	 Prob_forward: 2.2594022084376775e-06; Prob_backwards: 0.04757419973611832
# Word: is 	 Prob_forward: 0.008867845870554447; Prob_backwards: 0.9736267924308777
# Word: a 	 Prob_forward: 0.30896466970443726; Prob_backwards: 0.9003362059593201
# Word: multi 	 Prob_forward: 0.00037436443381011486; Prob_backwards: 0.899473249912262
# Word: ##ling 	 Prob_forward: 1.092221646104008e-05; Prob_backwards: 0.00010052024299511686
# Word: ##ual 	 Prob_forward: 0.9980555772781372; Prob_backwards: 1.407312737455868e-07
# Word: online 	 Prob_forward: 0.08630248159170151; Prob_backwards: 0.422554075717926
# Word: encyclopedia 	 Prob_forward: 0.11056102812290192; Prob_backwards: 8.86730788351997e-07
# Word: created 	 Prob_forward: 0.006859001703560352; Prob_backwards: 0.010943444445729256
# Word: and 	 Prob_forward: 0.00012321285612415522; Prob_backwards: 0.0013303019804880023
# Word: maintained 	 Prob_forward: 0.14865604043006897; Prob_backwards: 0.0012487202184274793
# Word: as 	 Prob_forward: 0.00035020586801692843; Prob_backwards: 0.0026871340814977884
# Word: an 	 Prob_forward: 0.0009029677021317184; Prob_backwards: 0.8993223309516907
# Word: open 	 Prob_forward: 0.050095345824956894; Prob_backwards: 0.0032574029173702
# Word: collaboration 	 Prob_forward: 5.396253072831314e-06; Prob_backwards: 0.00014947348972782493
# Word: project 	 Prob_forward: 0.00011226104834349826; Prob_backwards: 0.00013592018513008952
# Word: by 	 Prob_forward: 0.042942631989717484; Prob_backwards: 0.0008045929134823382
# Word: a 	 Prob_forward: 0.0011967672035098076; Prob_backwards: 0.6744857430458069
# Word: community 	 Prob_forward: 0.0031213818583637476; Prob_backwards: 0.020723046734929085
# Word: of 	 Prob_forward: 0.8823878169059753; Prob_backwards: 0.007973367348313332
# Word: volunteer 	 Prob_forward: 0.000843739602714777; Prob_backwards: 0.00017674914852250367
# Word: editors 	 Prob_forward: 0.03917354345321655; Prob_backwards: 5.955613232799806e-06
# Word: . 	 Prob_forward: 0.9987711310386658; Prob_backwards: 0.8574939966201782
# Geometric-mean forward sentence probability: 0.007003508740314713
# Geometric-mean backward sentence probability: 0.00612075686799311
#
# Average normalized sentence prob: 0.006547272273422807
#
# Processing sentence: ['[CLS]', 'once', 'she', 'gave', 'her', 'a', 'little', 'cap', 'of', 'red', 'velvet', ',', 'which', 'suited', 'her', 'so', 'well', 'that', 'she', 'would', 'never', 'wear', 'anything', 'else', '.', '[SEP]']
#
# Word: once 	 Prob_forward: 4.612844713847153e-05; Prob_backwards: 0.009982789866626263
# Word: she 	 Prob_forward: 0.058417413383722305; Prob_backwards: 0.0017481418326497078
# Word: gave 	 Prob_forward: 0.0006595153245143592; Prob_backwards: 0.6566595435142517
# Word: her 	 Prob_forward: 0.09845169633626938; Prob_backwards: 0.010984892956912518
# Word: a 	 Prob_forward: 0.0521705336868763; Prob_backwards: 0.8912469744682312
# Word: little 	 Prob_forward: 0.033869240432977676; Prob_backwards: 3.0722017982043326e-05
# Word: cap 	 Prob_forward: 0.00022106547839939594; Prob_backwards: 0.0003271881432738155
# Word: of 	 Prob_forward: 0.19444957375526428; Prob_backwards: 0.39071595668792725
# Word: red 	 Prob_forward: 0.02127726748585701; Prob_backwards: 0.282207727432251
# Word: velvet 	 Prob_forward: 0.006970690563321114; Prob_backwards: 2.668757406354416e-05
# Word: , 	 Prob_forward: 0.30088838934898376; Prob_backwards: 0.9576151371002197
# Word: which 	 Prob_forward: 0.0010807671351358294; Prob_backwards: 0.003944295458495617
# Word: suited 	 Prob_forward: 1.3381651115196291e-05; Prob_backwards: 0.014705170877277851
# Word: her 	 Prob_forward: 0.8620262145996094; Prob_backwards: 0.3574158549308777
# Word: so 	 Prob_forward: 0.004680860787630081; Prob_backwards: 0.26560449600219727
# Word: well 	 Prob_forward: 0.4516744315624237; Prob_backwards: 0.0002226558863185346
# Word: that 	 Prob_forward: 0.15837892889976501; Prob_backwards: 0.6809115409851074
# Word: she 	 Prob_forward: 0.693387508392334; Prob_backwards: 0.18473617732524872
# Word: would 	 Prob_forward: 0.031038792803883553; Prob_backwards: 0.4196990430355072
# Word: never 	 Prob_forward: 0.19093677401542664; Prob_backwards: 0.016853483393788338
# Word: wear 	 Prob_forward: 0.049916159361600876; Prob_backwards: 1.2531621905509382e-05
# Word: anything 	 Prob_forward: 0.0019421682227402925; Prob_backwards: 0.11654029041528702
# Word: else 	 Prob_forward: 0.6009309887886047; Prob_backwards: 3.0254355806391686e-05
# Word: . 	 Prob_forward: 0.9763575196266174; Prob_backwards: 0.8380947709083557
# Geometric-mean forward sentence probability: 0.03096447799513029
# Geometric-mean backward sentence probability: 0.022403986491739532
#
# Average normalized sentence prob: 0.026338711941297832
# 0.026338711941297832

# %%
# Load pre-trained model (weights)
with torch.no_grad():
    model = BertForMaskedLM.from_pretrained('bert-base-uncased')
    model.eval()
    # Load pre-trained model tokenizer (vocabulary)
    tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# %%
#get_sentence_prob("I fed my cat some of it and he damn near passed out")
get_sentence_prob("He was born in Berlin.")
get_sentence_prob("He was born in Santiago.")
get_sentence_prob("He was born in France.")
get_sentence_prob("He was born in window.")
get_sentence_prob("He was born in was.")
# Out:
# Processing sentence: ['[CLS]', 'he', 'was', 'born', 'in', 'berlin', '.', '[SEP]']
# Word: he 	 Prob_forward: 0.0021003505680710077; Prob_backwards: 0.8305719494819641
#
# Word: was 	 Prob_forward: 0.21391922235488892; Prob_backwards: 0.9997050166130066
#
# Word: born 	 Prob_forward: 0.00040079050813801587; Prob_backwards: 0.01874382235109806
#
# Word: in 	 Prob_forward: 0.980291485786438; Prob_backwards: 0.018296195194125175
#
# Word: berlin 	 Prob_forward: 0.02419455163180828; Prob_backwards: 9.928996587404981e-05
#
# Word: . 	 Prob_forward: 0.9961835741996765; Prob_backwards: 0.9829498529434204
#
#
# Geometric-mean forward sentence probability: 0.08986879181068508
#
#
# Geometric-mean backward sentence probability: 0.11362871557646786
#
#
# Average normalized sentence prob: 0.10105283461564618
#
# Processing sentence: ['[CLS]', 'he', 'was', 'born', 'in', 'santiago', '.', '[SEP]']
# Word: he 	 Prob_forward: 0.0021003505680710077; Prob_backwards: 0.7335055470466614
#
# Word: was 	 Prob_forward: 0.21391922235488892; Prob_backwards: 0.9991088509559631
#
# Word: born 	 Prob_forward: 0.00040079050813801587; Prob_backwards: 0.14439718425273895
#
# Word: in 	 Prob_forward: 0.980291485786438; Prob_backwards: 0.0005910049076192081
#
# Word: santiago 	 Prob_forward: 0.0012872583465650678; Prob_backwards: 4.421921039465815e-05
#
# Word: . 	 Prob_forward: 0.9926425814628601; Prob_backwards: 0.9829498529434204
#
#
# Geometric-mean forward sentence probability: 0.06225283113378822
#
#
# Geometric-mean backward sentence probability: 0.08497448554592857
#
#
# Average normalized sentence prob: 0.07273171453617204
#
# Processing sentence: ['[CLS]', 'he', 'was', 'born', 'in', 'france', '.', '[SEP]']
# Word: he 	 Prob_forward: 0.0021003505680710077; Prob_backwards: 0.8246520161628723
#
# Word: was 	 Prob_forward: 0.21391922235488892; Prob_backwards: 0.9993835687637329
#
# Word: born 	 Prob_forward: 0.00040079050813801587; Prob_backwards: 0.037675779312849045
#
# Word: in 	 Prob_forward: 0.980291485786438; Prob_backwards: 0.08316677063703537
#
# Word: france 	 Prob_forward: 0.0023899099323898554; Prob_backwards: 0.00020140780543442816
#
# Word: . 	 Prob_forward: 0.99676114320755; Prob_backwards: 0.9829498529434204
#
#
# Geometric-mean forward sentence probability: 0.06729353735480549
#
#
# Geometric-mean backward sentence probability: 0.16352261759004955
#
#
# Average normalized sentence prob: 0.10490002562035708
#
# Processing sentence: ['[CLS]', 'he', 'was', 'born', 'in', 'window', '.', '[SEP]']
# Word: he 	 Prob_forward: 0.0021003505680710077; Prob_backwards: 0.6349582076072693
#
# Word: was 	 Prob_forward: 0.21391922235488892; Prob_backwards: 0.9748175144195557
#
# Word: born 	 Prob_forward: 0.00040079050813801587; Prob_backwards: 7.31798354536295e-05
#
# Word: in 	 Prob_forward: 0.980291485786438; Prob_backwards: 0.00015780604735482484
#
# Word: window 	 Prob_forward: 1.2230869970153435e-06; Prob_backwards: 1.409893411619123e-05
#
# Word: . 	 Prob_forward: 0.9870637655258179; Prob_backwards: 0.9829498529434204
#
#
# Geometric-mean forward sentence probability: 0.026066162561798167
#
#
# Geometric-mean backward sentence probability: 0.023685777643319663
#
#
# Average normalized sentence prob: 0.024847481370420123
#
# Processing sentence: ['[CLS]', 'he', 'was', 'born', 'in', 'was', '.', '[SEP]']
# Word: he 	 Prob_forward: 0.0021003505680710077; Prob_backwards: 0.7539962530136108
#
# Word: was 	 Prob_forward: 0.21391922235488892; Prob_backwards: 0.9985907673835754
#
# Word: born 	 Prob_forward: 0.00040079050813801587; Prob_backwards: 0.00034775742096826434
#
# Word: in 	 Prob_forward: 0.980291485786438; Prob_backwards: 4.743799945572391e-05
#
# Word: was 	 Prob_forward: 1.2839785085816402e-05; Prob_backwards: 7.453393664036412e-06
#
# Word: . 	 Prob_forward: 0.9896163940429688; Prob_backwards: 0.9829498529434204
#
#
# Geometric-mean forward sentence probability: 0.03498282335602142
#
#
# Geometric-mean backward sentence probability: 0.02343584494207886
#
#
# Average normalized sentence prob: 0.028633058233584703
# 0.028633058233584703

# %%
get_sentence_prob("I fed my cat some of it and he damn near passed out.")
get_sentence_prob("I fed my dog some of it and he damn near passed out.")
get_sentence_prob("I fed my window some of it and he damn near passed out.")
get_sentence_prob("I fed my the some of it and he damn near passed out.")
# Out:
# Processing sentence: ['[CLS]', 'i', 'fed', 'my', 'cat', 'some', 'of', 'it', 'and', 'he', 'damn', 'near', 'passed', 'out', '.', '[SEP]']
# Word: i 	 Prob_forward: 0.00788011122494936; Prob_backwards: 0.9571204781532288
#
# Word: fed 	 Prob_forward: 0.0002093437797157094; Prob_backwards: 0.1745494306087494
#
# Word: my 	 Prob_forward: 0.001939286245033145; Prob_backwards: 0.02095809206366539
#
# Word: cat 	 Prob_forward: 0.0075833857990801334; Prob_backwards: 2.67108316620579e-06
#
# Word: some 	 Prob_forward: 0.02979872189462185; Prob_backwards: 0.0016446709632873535
#
# Word: of 	 Prob_forward: 0.002569902455434203; Prob_backwards: 0.014875434339046478
#
# Word: it 	 Prob_forward: 0.0014934015925973654; Prob_backwards: 4.503015225054696e-05
#
# Word: and 	 Prob_forward: 0.43204018473625183; Prob_backwards: 0.4202370047569275
#
# Word: he 	 Prob_forward: 0.037493497133255005; Prob_backwards: 0.09001420438289642
#
# Word: damn 	 Prob_forward: 3.998847751063295e-05; Prob_backwards: 0.8230639696121216
#
# Word: near 	 Prob_forward: 0.08850181847810745; Prob_backwards: 8.134087693179026e-05
#
# Word: passed 	 Prob_forward: 0.00022897911549080163; Prob_backwards: 0.008892068639397621
#
# Word: out 	 Prob_forward: 0.9834544658660889; Prob_backwards: 0.00014386186376214027
#
# Word: . 	 Prob_forward: 0.9980348944664001; Prob_backwards: 0.915639340877533
#
#
# Geometric-mean forward sentence probability: 0.01667547477760637
#
#
# Geometric-mean backward sentence probability: 0.016512955510577375
#
#
# Average normalized sentence prob: 0.016594016184166182
#
# Processing sentence: ['[CLS]', 'i', 'fed', 'my', 'dog', 'some', 'of', 'it', 'and', 'he', 'damn', 'near', 'passed', 'out', '.', '[SEP]']
# Word: i 	 Prob_forward: 0.00788011122494936; Prob_backwards: 0.9549459218978882
#
# Word: fed 	 Prob_forward: 0.0002093437797157094; Prob_backwards: 0.125798761844635
#
# Word: my 	 Prob_forward: 0.001939286245033145; Prob_backwards: 0.03677813708782196
#
# Word: dog 	 Prob_forward: 0.009720670990645885; Prob_backwards: 3.1380184850604564e-07
#
# Word: some 	 Prob_forward: 0.004785200115293264; Prob_backwards: 0.0016446709632873535
#
# Word: of 	 Prob_forward: 0.002817720640450716; Prob_backwards: 0.014875434339046478
#
# Word: it 	 Prob_forward: 0.002602030523121357; Prob_backwards: 4.503015225054696e-05
#
# Word: and 	 Prob_forward: 0.3616943955421448; Prob_backwards: 0.4202370047569275
#
# Word: he 	 Prob_forward: 0.05245253071188927; Prob_backwards: 0.09001420438289642
#
# Word: damn 	 Prob_forward: 6.438905256800354e-05; Prob_backwards: 0.8230639696121216
#
# Word: near 	 Prob_forward: 0.07292289286851883; Prob_backwards: 8.134087693179026e-05
#
# Word: passed 	 Prob_forward: 0.0001859292242443189; Prob_backwards: 0.008892068639397621
#
# Word: out 	 Prob_forward: 0.9816142916679382; Prob_backwards: 0.00014386186376214027
#
# Word: . 	 Prob_forward: 0.9981781244277954; Prob_backwards: 0.915639340877533
#
#
# Geometric-mean forward sentence probability: 0.015959071058304186
#
#
# Geometric-mean backward sentence probability: 0.014655843520062786
#
#
# Average normalized sentence prob: 0.015293581926941411
#
# Processing sentence: ['[CLS]', 'i', 'fed', 'my', 'window', 'some', 'of', 'it', 'and', 'he', 'damn', 'near', 'passed', 'out', '.', '[SEP]']
# Word: i 	 Prob_forward: 0.00788011122494936; Prob_backwards: 0.6795225143432617
#
# Word: fed 	 Prob_forward: 0.0002093437797157094; Prob_backwards: 1.5038370293041226e-05
#
# Word: my 	 Prob_forward: 0.001939286245033145; Prob_backwards: 0.05881839990615845
#
# Word: window 	 Prob_forward: 0.000105426246591378; Prob_backwards: 3.253963086535805e-06
#
# Word: some 	 Prob_forward: 6.158111500553787e-05; Prob_backwards: 0.0016446709632873535
#
# Word: of 	 Prob_forward: 0.0020776770543307066; Prob_backwards: 0.014875434339046478
#
# Word: it 	 Prob_forward: 0.000887697737198323; Prob_backwards: 4.503015225054696e-05
#
# Word: and 	 Prob_forward: 0.15423624217510223; Prob_backwards: 0.4202370047569275
#
# Word: he 	 Prob_forward: 0.019063521176576614; Prob_backwards: 0.09001420438289642
#
# Word: damn 	 Prob_forward: 8.814126340439543e-05; Prob_backwards: 0.8230639696121216
#
# Word: near 	 Prob_forward: 0.12746453285217285; Prob_backwards: 8.134087693179026e-05
#
# Word: passed 	 Prob_forward: 0.0004978197976015508; Prob_backwards: 0.008892068639397621
#
# Word: out 	 Prob_forward: 0.9807475209236145; Prob_backwards: 0.00014386186376214027
#
# Word: . 	 Prob_forward: 0.9969933032989502; Prob_backwards: 0.915639340877533
#
#
# Geometric-mean forward sentence probability: 0.008401311796276529
#
#
# Geometric-mean backward sentence probability: 0.009724117745912355
#
#
# Average normalized sentence prob: 0.009038547733298498
#
# Processing sentence: ['[CLS]', 'i', 'fed', 'my', 'the', 'some', 'of', 'it', 'and', 'he', 'damn', 'near', 'passed', 'out', '.', '[SEP]']
# Word: i 	 Prob_forward: 0.00788011122494936; Prob_backwards: 0.47843486070632935
#
# Word: fed 	 Prob_forward: 0.0002093437797157094; Prob_backwards: 0.010456575080752373
#
# Word: my 	 Prob_forward: 0.001939286245033145; Prob_backwards: 3.7444471672642976e-05
#
# Word: the 	 Prob_forward: 0.00037052115658298135; Prob_backwards: 0.0001865382946562022
#
# Word: some 	 Prob_forward: 0.000161071409820579; Prob_backwards: 0.0016446709632873535
#
# Word: of 	 Prob_forward: 0.014817040413618088; Prob_backwards: 0.014875434339046478
#
# Word: it 	 Prob_forward: 0.059601932764053345; Prob_backwards: 4.503015225054696e-05
#
# Word: and 	 Prob_forward: 0.25348716974258423; Prob_backwards: 0.4202370047569275
#
# Word: he 	 Prob_forward: 0.043495193123817444; Prob_backwards: 0.09001420438289642
#
# Word: damn 	 Prob_forward: 5.815671102027409e-05; Prob_backwards: 0.8230639696121216
#
# Word: near 	 Prob_forward: 0.09678072482347488; Prob_backwards: 8.134087693179026e-05
#
# Word: passed 	 Prob_forward: 0.00044285229523666203; Prob_backwards: 0.008892068639397621
#
# Word: out 	 Prob_forward: 0.9698404669761658; Prob_backwards: 0.00014386186376214027
#
# Word: . 	 Prob_forward: 0.9969468712806702; Prob_backwards: 0.915639340877533
#
#
# Geometric-mean forward sentence probability: 0.014645579031472651
#
#
# Geometric-mean backward sentence probability: 0.011644009429458892
#
#
# Average normalized sentence prob: 0.013058838399427147
# 0.013058838399427147

# %%
print("Should have similar/high probs\n")
get_sentence_prob("I forgot to take my medicine.")
get_sentence_prob("I forgot to take my medicines.")
get_sentence_prob("I forgot to take my medication.")
get_sentence_prob("I forgot to take my pills.")
print("Should have low probs\n")
get_sentence_prob("I forgot to take my turn.")
get_sentence_prob("I forgot to take my medical.")
get_sentence_prob("I forgot to take my medically.")
get_sentence_prob("I forgot to take my turned.")
# Out:
# Should have similar/high probs
#
# Processing sentence: ['[CLS]', 'i', 'forgot', 'to', 'take', 'my', 'medicine', '.', '[SEP]']
# Word: i 	 Prob_forward: 0.009378484450280666; Prob_backwards: 0.9732086658477783
#
# Word: forgot 	 Prob_forward: 0.00021250064310152084; Prob_backwards: 0.015700489282608032
#
# Word: to 	 Prob_forward: 0.03624541684985161; Prob_backwards: 0.055403366684913635
#
# Word: take 	 Prob_forward: 0.017103174701333046; Prob_backwards: 0.02183195948600769
#
# Word: my 	 Prob_forward: 0.00037714111385867; Prob_backwards: 2.8737551474478096e-05
#
# Word: medicine 	 Prob_forward: 0.01692848652601242; Prob_backwards: 1.0145240594283678e-06
#
# Word: . 	 Prob_forward: 0.9715754985809326; Prob_backwards: 0.9818249344825745
#
#
# Geometric-mean forward sentence probability: 0.027014838021123058
#
#
# Geometric-mean backward sentence probability: 0.02007291597720789
#
#
# Average normalized sentence prob: 0.023286617911063946
#
# Processing sentence: ['[CLS]', 'i', 'forgot', 'to', 'take', 'my', 'medicines', '.', '[SEP]']
# Word: i 	 Prob_forward: 0.009378484450280666; Prob_backwards: 0.959055483341217
#
# Word: forgot 	 Prob_forward: 0.00021250064310152084; Prob_backwards: 0.03440174460411072
#
# Word: to 	 Prob_forward: 0.03624541684985161; Prob_backwards: 0.036071665585041046
#
# Word: take 	 Prob_forward: 0.017103174701333046; Prob_backwards: 0.027487343177199364
#
# Word: my 	 Prob_forward: 0.00037714111385867; Prob_backwards: 4.7293051466112956e-05
#
# Word: medicines 	 Prob_forward: 0.0010721920989453793; Prob_backwards: 1.3588584124590852e-07
#
# Word: . 	 Prob_forward: 0.9502522945404053; Prob_backwards: 0.9818249344825745
#
#
# Geometric-mean forward sentence probability: 0.019832707928753426
#
#
# Geometric-mean backward sentence probability: 0.01807973615100691
#
#
# Average normalized sentence prob: 0.01893594799612221
#
# Processing sentence: ['[CLS]', 'i', 'forgot', 'to', 'take', 'my', 'medication', '.', '[SEP]']
# Word: i 	 Prob_forward: 0.009378484450280666; Prob_backwards: 0.9826751947402954
#
# Word: forgot 	 Prob_forward: 0.00021250064310152084; Prob_backwards: 0.019755234941840172
#
# Word: to 	 Prob_forward: 0.03624541684985161; Prob_backwards: 0.035435281693935394
#
# Word: take 	 Prob_forward: 0.017103174701333046; Prob_backwards: 0.03981746733188629
#
# Word: my 	 Prob_forward: 0.00037714111385867; Prob_backwards: 0.0002998834534082562
#
# Word: medication 	 Prob_forward: 0.026077212765812874; Prob_backwards: 5.510057121682621e-07
#
# Word: . 	 Prob_forward: 0.9752807021141052; Prob_backwards: 0.9818249344825745
#
#
# Geometric-mean forward sentence probability: 0.02835536658682786
#
#
# Geometric-mean backward sentence probability: 0.02542757438804265
#
#
# Average normalized sentence prob: 0.02685159572887214
#
# Processing sentence: ['[CLS]', 'i', 'forgot', 'to', 'take', 'my', 'pills', '.', '[SEP]']
# Word: i 	 Prob_forward: 0.009378484450280666; Prob_backwards: 0.9777646064758301
#
# Word: forgot 	 Prob_forward: 0.00021250064310152084; Prob_backwards: 0.1108216792345047
#
# Word: to 	 Prob_forward: 0.03624541684985161; Prob_backwards: 0.0941462367773056
#
# Word: take 	 Prob_forward: 0.017103174701333046; Prob_backwards: 0.0912068709731102
#
# Word: my 	 Prob_forward: 0.00037714111385867; Prob_backwards: 0.005478112958371639
#
# Word: pills 	 Prob_forward: 0.022128582000732422; Prob_backwards: 4.7535141334265063e-07
#
# Word: . 	 Prob_forward: 0.9657054543495178; Prob_backwards: 0.9818249344825745
#
#
# Geometric-mean forward sentence probability: 0.027812248393721366
#
#
# Geometric-mean backward sentence probability: 0.051107599985195803
#
#
# Average normalized sentence prob: 0.03770168783483328
#
# Should have low probs
#
# Processing sentence: ['[CLS]', 'i', 'forgot', 'to', 'take', 'my', 'turn', '.', '[SEP]']
# Word: i 	 Prob_forward: 0.009378484450280666; Prob_backwards: 0.9735077023506165
#
# Word: forgot 	 Prob_forward: 0.00021250064310152084; Prob_backwards: 0.00034846997004933655
#
# Word: to 	 Prob_forward: 0.03624541684985161; Prob_backwards: 0.3529961407184601
#
# Word: take 	 Prob_forward: 0.017103174701333046; Prob_backwards: 0.0018182012718170881
#
# Word: my 	 Prob_forward: 0.00037714111385867; Prob_backwards: 0.06494130939245224
#
# Word: turn 	 Prob_forward: 0.003556604031473398; Prob_backwards: 1.5019260501958343e-07
#
# Word: . 	 Prob_forward: 0.9719839096069336; Prob_backwards: 0.9818249344825745
#
#
# Geometric-mean forward sentence probability: 0.022716200185818467
#
#
# Geometric-mean backward sentence probability: 0.023377127447665492
#
#
# Average normalized sentence prob: 0.023044294453737586
#
# Processing sentence: ['[CLS]', 'i', 'forgot', 'to', 'take', 'my', 'medical', '.', '[SEP]']
# Word: i 	 Prob_forward: 0.009378484450280666; Prob_backwards: 0.9557051062583923
#
# Word: forgot 	 Prob_forward: 0.00021250064310152084; Prob_backwards: 0.014033556915819645
#
# Word: to 	 Prob_forward: 0.03624541684985161; Prob_backwards: 0.059686329215765
#
# Word: take 	 Prob_forward: 0.017103174701333046; Prob_backwards: 0.0036742594093084335
#
# Word: my 	 Prob_forward: 0.00037714111385867; Prob_backwards: 7.4269381002523e-05
#
# Word: medical 	 Prob_forward: 3.781436680583283e-05; Prob_backwards: 4.669530881074024e-06
#
# Word: . 	 Prob_forward: 0.9808206558227539; Prob_backwards: 0.9818249344825745
#
#
# Geometric-mean forward sentence probability: 0.013724866104624017
#
#
# Geometric-mean backward sentence probability: 0.02154794888506526
#
#
# Average normalized sentence prob: 0.0171971716650385
#
# Processing sentence: ['[CLS]', 'i', 'forgot', 'to', 'take', 'my', 'medical', '##ly', '.', '[SEP]']
# Word: i 	 Prob_forward: 0.009913097135722637; Prob_backwards: 0.8403862118721008
#
# Word: forgot 	 Prob_forward: 0.00014892553735990077; Prob_backwards: 0.007657377049326897
#
# Word: to 	 Prob_forward: 0.005886345636099577; Prob_backwards: 0.046000342816114426
#
# Word: take 	 Prob_forward: 0.0385177917778492; Prob_backwards: 0.007178690750151873
#
# Word: my 	 Prob_forward: 0.1262291669845581; Prob_backwards: 1.1252015610807575e-05
#
# Word: medical 	 Prob_forward: 0.00020528965978883207; Prob_backwards: 0.00012155887088738382
#
# Word: ##ly 	 Prob_forward: 0.0002183810865972191; Prob_backwards: 0.003725613234564662
#
# Word: . 	 Prob_forward: 0.9684106111526489; Prob_backwards: 0.9721716642379761
#
#
# Geometric-mean forward sentence probability: 0.01684025655763369
#
#
# Geometric-mean backward sentence probability: 0.020055444773566695
#
#
# Average normalized sentence prob: 0.018377672196562785
#
# Processing sentence: ['[CLS]', 'i', 'forgot', 'to', 'take', 'my', 'turned', '.', '[SEP]']
# Word: i 	 Prob_forward: 0.009378484450280666; Prob_backwards: 0.9284183382987976
#
# Word: forgot 	 Prob_forward: 0.00021250064310152084; Prob_backwards: 0.003320510732010007
#
# Word: to 	 Prob_forward: 0.03624541684985161; Prob_backwards: 0.6746736764907837
#
# Word: take 	 Prob_forward: 0.017103174701333046; Prob_backwards: 0.0006200186908245087
#
# Word: my 	 Prob_forward: 0.00037714111385867; Prob_backwards: 3.881300654029474e-05
#
# Word: turned 	 Prob_forward: 3.3881631679832935e-05; Prob_backwards: 1.032800696521008e-06
#
# Word: . 	 Prob_forward: 0.963825523853302; Prob_backwards: 0.9818249344825745
#
#
# Geometric-mean forward sentence probability: 0.013532108791580367
#
#
# Geometric-mean backward sentence probability: 0.015470245962661146
#
#
# Average normalized sentence prob: 0.014468761225455259
# 0.014468761225455259
